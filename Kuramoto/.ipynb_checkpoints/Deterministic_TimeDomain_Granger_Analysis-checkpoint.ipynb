# %%
import numpy as np
from pandas.plotting import table
import pandas as pd
import nbimporter
from Kuramoto_dynamicalModels import *
import statsmodels.api as sm
from statsmodels.tsa.api import VAR, DynamicVAR
from statsmodels.tsa.tsatools import detrend
import statsmodels
import matplotlib.pyplot as plt
abs_path = '/Users/aarcher/PycharmProjects/Data Driven Dynamical Systems/Kuramoto/pictures/'
# Out:
# Importing Jupyter notebook from Kuramoto_dynamicalModels.ipynb

# %%
def granger_casuality_table(df):
    num_cols = len(df.columns)
    colnames = df.columns.values
    
    df_results = pd.DataFrame(index=colnames, columns=colnames)
    df_results = df_results.fillna(0)
    model = VAR(df)
    #fit to VAR model with AIC

    VAR_results = model.fit(ic='aic',trend='nc')

    for row in colnames:
        for col in colnames:
            if not row == col:
                #determine casuality among different angles
                causal_results = VAR_results.test_causality(col, row, kind='Wald')
                causality_conclusion =causal_results.conclusion
                if causality_conclusion == 'reject':
                    df_results.loc[row,col]='GC'
                elif causality_conclusion == 'fail to reject':
                    df_results.loc[row,col]='not GC'
                    
    return df_results

# %% [markdown]
# # Strong Coupling

# %%
# these are our constants
N = 5  # number of variables
K = 10 #coupling
omega =  np.array([ 2.31246433, 35.50794494, 53.41350736, 50.23353682,  5.63392492])  # natural frequency
theta0 = np.array([1.1735002435, 2.6194283291, 2.6006912657, 2.9369995793,2.3511319532]) # initial state 
tinit = 0.0
tmax = 10.0
dt =  0.01

# %%
kuramoto = Kuramoto(N,K,omega)
sol = kuramoto.integrate(tinit, 20, dt, theta0)
kuramoto.evolution_plot()
kuramoto.trajectory_plot()

# %%
kuramoto = Kuramoto(N,K,omega)
sol = kuramoto.integrate(tinit, tmax, dt, theta0)
kuramoto.evolution_plot()
kuramoto.trajectory_plot()

# %%
y = detrend(sol[1])
kuramoto_df = pd.DataFrame(data=y,    
                columns=['\Theta_0','\Theta_1','\Theta_2','\Theta_3','\Theta_4'])


kuramoto_transform_df = kuramoto_df.transform([np.cos,np.sin])
kuramoto_transform_df.columns = [''.join(['$\\' + col[1] + col[0] +'$']).strip() for col in kuramoto_transform_df.columns.values]

# %%
#plot detrended data
kuramoto_df.columns = ['$\\Theta_0$','$\\Theta_1$','$\\Theta_2$','$\\Theta_3$','$\\Theta_4$']
plt.plot(sol[0],kuramoto_df)
plt.xlabel('time')
plt.ylabel('Angle')
plt.title('Detrend Angle Data')
plt.legend(kuramoto_df.columns)
plt.savefig(abs_path+'detrended_angle_data_strong_coupling_deterministickuramoto.png',bbox_inches='tight')
plt.show()


#compute granger causality of detrended data
results_df= granger_casuality_table(kuramoto_df)
ax = plt.subplot(111, frame_on=False) # no visible frame
ax.xaxis.set_visible(False)  # hide the x axis
ax.yaxis.set_visible(False)  # hide the y axis
table(ax, results_df,loc='center')  # where df is your data frame

plt.savefig(abs_path+'strong_coupling_angular_Granger_deterministickuramoto.png',bbox_inches='tight')
plt.show()

# %%
results_df= granger_casuality_table(kuramoto_transform_df)
ax = plt.subplot(111, frame_on=False) # no visible frame
ax.xaxis.set_visible(False)  # hide the x axis
ax.yaxis.set_visible(False)  # hide the y axis

table(ax, results_df,loc='center')  # where df is your data frame

plt.savefig(abs_path+'strong_coupling_Granger_deterministickuramoto.png',bbox_inches='tight')
plt.show()

# %% [markdown]
# # Weak Coupling

# %%
# these are our constants
N = 5  # number of variables
K = 1.0 #coupling
omega =  np.array([ 2.31246433, 35.50794494, 53.41350736, 50.23353682,  5.63392492])  # natural frequency
theta0 = np.array([1.1735002435, 2.6194283291, 2.6006912657, 2.9369995793,2.3511319532]) # initial state 
tinit = 0.0
tmax = 10.0
dt =  0.01

# %%
kuramoto = Kuramoto(N,K,omega)
sol = kuramoto.integrate(tinit, tmax, dt, theta0)
kuramoto.evolution_plot()
kuramoto.trajectory_plot()

# %%
kuramoto = Kuramoto(N,K,omega)
sol = kuramoto.integrate(tinit, tmax, dt, theta0)
kuramoto.evolution_plot()
kuramoto.trajectory_plot()

# %%
y = detrend(sol[1])
kuramoto_df = pd.DataFrame(data=y,    
                columns=['\Theta_0','\Theta_1','\Theta_2','\Theta_3','\Theta_4'])
kuramoto_transform_df = kuramoto_df.transform([np.cos,np.sin])
kuramoto_transform_df.columns = [''.join(['$\\' + col[1] + col[0] +'$']).strip() for col in kuramoto_transform_df.columns.values]

# %%
#plot detrended data
kuramoto_df.columns = ['$\\Theta_0$','$\\Theta_1$','$\\Theta_2$','$\\Theta_3$','$\\Theta_4$']
plt.plot(sol[0],kuramoto_df)
plt.xlabel('time')
plt.ylabel('Angle')
plt.title('Detrend Angle Data')
plt.legend(kuramoto_df.columns)
plt.savefig(abs_path+'detrended_angle_data_weak_coupling_deterministickuramoto.png',bbox_inches='tight')
plt.show()


#compute granger causality of detrended data
results_df= granger_casuality_table(kuramoto_df)
ax = plt.subplot(111, frame_on=False) # no visible frame
ax.xaxis.set_visible(False)  # hide the x axis
ax.yaxis.set_visible(False)  # hide the y axis
table(ax, results_df,loc='center')  # where df is your data frame

plt.savefig(abs_path+'weak_coupling_angular_Granger_deterministickuramoto.png',bbox_inches='tight')
plt.show()

# %%
results_df= granger_casuality_table(kuramoto_transform_df)
ax = plt.subplot(111, frame_on=False) # no visible frame
ax.xaxis.set_visible(False)  # hide the x axis
ax.yaxis.set_visible(False)  # hide the y axis

table(ax, results_df,loc='center')  # where df is your data frame

plt.savefig(abs_path+'weak_coupling_Granger_deterministickuramoto.png',bbox_inches='tight')
plt.show()

# %% [markdown]
# # No Coupling

# %%
# these are our constants
N = 5  # number of variables
K = 0 #coupling
omega =  np.array([ 2.31246433, 35.50794494, 53.41350736, 50.23353682,  5.63392492])  # natural frequency
theta0 = np.array([1.1735002435, 2.6194283291, 2.6006912657, 2.9369995793,2.3511319532]) # initial state 
tinit = 0.0
tmax = 10.0
dt =  0.01

# %%
kuramoto = Kuramoto(N,K,omega)
sol = kuramoto.integrate(tinit, tmax, dt, theta0)
kuramoto.evolution_plot()
kuramoto.trajectory_plot()

# %%
y = detrend(sol[1])
kuramoto_df = pd.DataFrame(data=y,    
                columns=['\Theta_0','\Theta_1','\Theta_2','\Theta_3','\Theta_4'])
kuramoto_transform_df = kuramoto_df.transform([np.cos,np.sin])
kuramoto_transform_df.columns = [''.join(['$\\' + col[1] + col[0] +'$']).strip() for col in kuramoto_transform_df.columns.values]

# %%
# results_df= granger_casuality_table(kuramoto_transform_df)
# ax = plt.subplot(111, frame_on=False) # no visible frame
# ax.xaxis.set_visible(False)  # hide the x axis
# ax.yaxis.set_visible(False)  # hide the y axis

# table(ax, results_df,loc='center')  # where df is your data frame

# plt.savefig(abs_path+'no_coupling_Granger_deterministickuramoto.png',bbox_inches='tight')
# plt.show()

# %%
#plot detrended data
kuramoto_df.columns = ['$\\Theta_0$','$\\Theta_1$','$\\Theta_2$','$\\Theta_3$','$\\Theta_4$']
plt.plot(sol[0],kuramoto_df)
plt.xlabel('time')
plt.ylabel('Angle')
plt.title('Detrend Angle Data')
plt.legend(kuramoto_df.columns)
plt.savefig(abs_path+'detrended_angle_data_no_coupling_deterministickuramoto.png',bbox_inches='tight')
plt.show()


#compute granger causality of detrended data
results_df= granger_casuality_table(kuramoto_df)
ax = plt.subplot(111, frame_on=False) # no visible frame
ax.xaxis.set_visible(False)  # hide the x axis
ax.yaxis.set_visible(False)  # hide the y axis
table(ax, results_df,loc='center')  # where df is your data frame

plt.savefig(abs_path+'no_coupling_angular_Granger_deterministickuramoto.png',bbox_inches='tight')
plt.show()
