# %%
import numpy as np
import pandas as pd
import nbimporter
from Kuramoto_dynamicalModels import *
import statsmodels.api as sm
from statsmodels.tsa.api import VAR, DynamicVAR
from statsmodels.tsa.tsatools import detrend
import statsmodels
import matplotlib.pyplot as plt

# %% [markdown]
# # Strong Coupling

# %%
# these are our constants
N = 5  # number of variables
K = 10 #coupling
omega =  np.array([ 2.31246433, 35.50794494, 53.41350736, 50.23353682,  5.63392492])  # natural frequency
theta0 = np.array([117.35002435, 261.94283291, 260.06912657, 293.69995793,235.11319532]) # initial state 
tinit = 0.0
tmax = 100.0
dt =  0.01

# %%
kuramoto = Kuramoto(N,K,omega)
sol = kuramoto.integrate(tinit, 20, dt, theta0)
kuramoto.evolution_plot()
kuramoto.trajectory_plot()

# %%
kuramoto = Kuramoto(N,K,omega)
sol = kuramoto.integrate(tinit, tmax, dt, theta0)
kuramoto.evolution_plot()
kuramoto.trajectory_plot()

# %%
kuramoto_df = pd.DataFrame(data= sol[1],    
                columns=['x0','x1','x2','x3','x4'])
kuramoto_df = kuramoto_df.transform([np.cos,np.sin])
kuramoto_df.columns = [''.join(col).strip() for col in kuramoto_df.columns.values]

# %%
kuramoto_df_wo_x0sin=kuramoto_df.drop(columns=['x0sin'])
model = VAR(kuramoto_df_wo_x0sin)
#find optimal lag order by information criteria
lag_orders_data = model.select_order(trend='nc')
print(lag_orders_data.selected_orders)
# Out:
# {'aic': 38, 'bic': 38, 'hqic': 38, 'fpe': 38}

# %%
results = model.fit(lag_orders_data.selected_orders['bic'],trend='nc')
print(results.summary())
# Out:
# /usr/local/lib/python3.6/site-packages/statsmodels/tsa/vector_ar/var_model.py:1387: RuntimeWarning: invalid value encountered in sqrt
#   stderr = np.sqrt(np.diag(self.cov_params))
# /usr/local/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /usr/local/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /usr/local/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 06, Jun, 2019
# Time:                     23:25:29
# --------------------------------------------------------------------
# No. of Equations:         9.00000    BIC:                   -250.489
# Nobs:                     9963.00    HQIC:                  -251.961
# Log likelihood:       1.13475e+06    FPE:               1.76755e-110
# AIC:                     -252.715    Det(Omega_mle):    1.30452e-110
# --------------------------------------------------------------------
# Results for equation x0cos
# ============================================================================
#                coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------
# L1.x0cos          4.754772         0.007761          612.617           0.000
# L1.x1cos          0.094775         0.011176            8.480           0.000
# L1.x1sin         -0.022833         0.007391           -3.089           0.002
# L1.x2cos         -0.159915         0.031433           -5.088           0.000
# L1.x2sin          0.592315         0.017243           34.352           0.000
# L1.x3cos          0.563895         0.011063           50.971           0.000
# L1.x3sin          0.550450         0.014737           37.351           0.000
# L1.x4cos          0.266200         0.012792           20.810           0.000
# L1.x4sin          0.660015         0.025710           25.671           0.000
# L2.x0cos        -11.984944         0.036806         -325.626           0.000
# L2.x1cos         -0.386565         0.065064           -5.941           0.000
# L2.x1sin          0.109593         0.038190            2.870           0.004
# L2.x2cos         -2.696432         0.109584          -24.606           0.000
# L2.x2sin         -2.420360         0.164309          -14.730           0.000
# L2.x3cos         -4.769997         0.054426          -87.641           0.000
# L2.x3sin          1.489852         0.073485           20.274           0.000
# L2.x4cos         -0.483468         0.025852          -18.701           0.000
# L2.x4sin         -5.137167         0.150989          -34.023           0.000
# L3.x0cos         22.130576         0.092830          238.398           0.000
# L3.x1cos          1.349617         0.140279            9.621           0.000
# L3.x1sin         -0.113365         0.153467           -0.739           0.460
# L3.x2cos          9.394305         0.303559           30.947           0.000
# L3.x2sin         -4.496872         0.416175          -10.805           0.000
# L3.x3cos          2.851925         0.236243           12.072           0.000
# L3.x3sin        -15.058148              NAN              NAN             NAN
# L3.x4cos         -3.360034         0.164828          -20.385           0.000
# L3.x4sin         16.733991         0.359209           46.586           0.000
# L4.x0cos        -33.273020         0.162738         -204.457           0.000
# L4.x1cos         -3.862329         0.173775          -22.226           0.000
# L4.x1sin          1.049794         0.327450            3.206           0.001
# L4.x2cos          3.053047         0.748692            4.078           0.000
# L4.x2sin         19.728410         0.282724           69.780           0.000
# L4.x3cos         24.113734              NAN              NAN             NAN
# L4.x3sin         19.077463         0.419399           45.488           0.000
# L4.x4cos         18.042235         0.599829           30.079           0.000
# L4.x4sin        -32.853560         0.226339         -145.152           0.000
# L5.x0cos         42.574596         0.214256          198.709           0.000
# L5.x1cos          6.498172         0.192492           33.758           0.000
# L5.x1sin         -5.260527         0.425506          -12.363           0.000
# L5.x2cos        -31.072193         0.678928          -45.767           0.000
# L5.x2sin         -1.392525              NAN              NAN             NAN
# L5.x3cos        -42.451556         0.173071         -245.285           0.000
# L5.x3sin         18.812879         0.554067           33.954           0.000
# L5.x4cos        -47.616993         1.041221          -45.732           0.000
# L5.x4sin         44.595039              NAN              NAN             NAN
# L6.x0cos        -48.888288         0.243184         -201.034           0.000
# L6.x1cos         -5.050308              NAN              NAN             NAN
# L6.x1sin         12.486400         0.425925           29.316           0.000
# L6.x2cos         10.848361              NAN              NAN             NAN
# L6.x2sin        -42.246514         0.869667          -48.578           0.000
# L6.x3cos          4.861152         0.908904            5.348           0.000
# L6.x3sin        -56.787128              NAN              NAN             NAN
# L6.x4cos         87.799225         0.637976          137.621           0.000
# L6.x4sin        -40.195433              NAN              NAN             NAN
# L7.x0cos         52.806342         0.266488          198.156           0.000
# L7.x1cos         -2.747717         0.113993          -24.104           0.000
# L7.x1sin        -18.576654         0.339867          -54.659           0.000
# L7.x2cos         44.471125              NAN              NAN             NAN
# L7.x2sin         27.373350              NAN              NAN             NAN
# L7.x3cos         48.100192              NAN              NAN             NAN
# L7.x3sin         33.816252         0.847083           39.921           0.000
# L7.x4cos       -123.409646              NAN              NAN             NAN
# L7.x4sin         10.762416         0.847403           12.700           0.000
# L8.x0cos        -53.598253         0.230747         -232.281           0.000
# L8.x1cos         15.225514         0.369291           41.229           0.000
# L8.x1sin         19.630509         0.580098           33.840           0.000
# L8.x2cos        -40.306404              NAN              NAN             NAN
# L8.x2sin         28.441886              NAN              NAN             NAN
# L8.x3cos        -47.942154         0.841705          -56.958           0.000
# L8.x3sin         20.446542         0.068028          300.562           0.000
# L8.x4cos        135.407602              NAN              NAN             NAN
# L8.x4sin         40.103836              NAN              NAN             NAN
# L9.x0cos         50.271417              NAN              NAN             NAN
# L9.x1cos        -29.539768         0.544608          -54.240           0.000
# L9.x1sin        -13.176415         0.910489          -14.472           0.000
# L9.x2cos         -0.658700         0.779439           -0.845           0.398
# L9.x2sin        -33.894220              NAN              NAN             NAN
# L9.x3cos          8.805419              NAN              NAN             NAN
# L9.x3sin        -40.915118         0.854795          -47.865           0.000
# L9.x4cos       -114.097503         0.552703         -206.435           0.000
# L9.x4sin        -93.621195              NAN              NAN             NAN
# L10.x0cos       -44.556098              NAN              NAN             NAN
# L10.x1cos        40.627875         0.509421           79.753           0.000
# L10.x1sin        -3.237881         0.972991           -3.328           0.001
# L10.x2cos         3.075423         0.290322           10.593           0.000
# L10.x2sin        19.080327         0.766118           24.905           0.000
# L10.x3cos        20.032853              NAN              NAN             NAN
# L10.x3sin        27.335264         0.451734           60.512           0.000
# L10.x4cos        66.104415              NAN              NAN             NAN
# L10.x4sin       128.698411              NAN              NAN             NAN
# L11.x0cos        38.812644              NAN              NAN             NAN
# L11.x1cos       -39.807484              NAN              NAN             NAN
# L11.x1sin        27.463841         0.993509           27.643           0.000
# L11.x2cos       -10.160027         0.438995          -23.144           0.000
# L11.x2sin       -38.566389         0.141816         -271.946           0.000
# L11.x3cos       -31.063674         0.316900          -98.024           0.000
# L11.x3sin        -4.006298              NAN              NAN             NAN
# L11.x4cos        -8.123993              NAN              NAN             NAN
# L11.x4sin      -136.136209         0.580690         -234.439           0.000
# L12.x0cos       -33.740428              NAN              NAN             NAN
# L12.x1cos        22.078027              NAN              NAN             NAN
# L12.x1sin       -49.034543         0.515142          -95.186           0.000
# L12.x2cos        62.178571              NAN              NAN             NAN
# L12.x2sin        29.757444         0.509930           58.356           0.000
# L12.x3cos        21.115254         0.335662           62.906           0.000
# L12.x3sin       -25.537463              NAN              NAN             NAN
# L12.x4cos       -44.113537              NAN              NAN             NAN
# L12.x4sin       117.036589         0.402207          290.986           0.000
# L13.x0cos        29.804498              NAN              NAN             NAN
# L13.x1cos         7.236374              NAN              NAN             NAN
# L13.x1sin        56.663353              NAN              NAN             NAN
# L13.x2cos       -77.710865         0.722243         -107.597           0.000
# L13.x2sin        47.483796              NAN              NAN             NAN
# L13.x3cos        22.813532              NAN              NAN             NAN
# L13.x3sin        32.067440         0.392643           81.671           0.000
# L13.x4cos        79.704338              NAN              NAN             NAN
# L13.x4sin       -76.258338              NAN              NAN             NAN
# L14.x0cos       -27.732035              NAN              NAN             NAN
# L14.x1cos       -37.049427         0.733714          -50.496           0.000
# L14.x1sin       -46.327381              NAN              NAN             NAN
# L14.x2cos         0.135178         0.125055            1.081           0.280
# L14.x2sin      -105.146830              NAN              NAN             NAN
# L14.x3cos       -48.044871              NAN              NAN             NAN
# L14.x3sin        24.819368         0.523208           47.437           0.000
# L14.x4cos       -91.364283              NAN              NAN             NAN
# L14.x4sin        22.786280              NAN              NAN             NAN
# L15.x0cos        26.401641              NAN              NAN             NAN
# L15.x1cos        56.872392         1.027203           55.366           0.000
# L15.x1sin        21.103991              NAN              NAN             NAN
# L15.x2cos        96.538576              NAN              NAN             NAN
# L15.x2sin        57.085636              NAN              NAN             NAN
# L15.x3cos       -19.366017         0.915703          -21.149           0.000
# L15.x3sin       -72.843905              NAN              NAN             NAN
# L15.x4cos        75.605372         0.224893          336.184           0.000
# L15.x4sin        27.652100         0.448151           61.703           0.000
# L16.x0cos       -23.621654              NAN              NAN             NAN
# L16.x1cos       -59.623589         1.068469          -55.803           0.000
# L16.x1sin        10.861168         0.437050           24.851           0.000
# L16.x2cos       -94.316690              NAN              NAN             NAN
# L16.x2sin        55.587356              NAN              NAN             NAN
# L16.x3cos        94.945576         0.590249          160.857           0.000
# L16.x3sin         5.136222         0.284586           18.048           0.000
# L16.x4cos       -39.912284         0.496221          -80.433           0.000
# L16.x4sin       -57.611163              NAN              NAN             NAN
# L17.x0cos        19.050697              NAN              NAN             NAN
# L17.x1cos        44.388429         0.374413          118.555           0.000
# L17.x1sin       -38.733211         0.507524          -76.318           0.000
# L17.x2cos        -7.307081              NAN              NAN             NAN
# L17.x2sin       -96.574494         0.219385         -440.206           0.000
# L17.x3cos       -47.401577         1.071699          -44.230           0.000
# L17.x3sin        94.115911              NAN              NAN             NAN
# L17.x4cos         2.673557              NAN              NAN             NAN
# L17.x4sin        62.137634         0.479417          129.611           0.000
# L18.x0cos       -14.431091         0.121522         -118.753           0.000
# L18.x1cos       -16.967566              NAN              NAN             NAN
# L18.x1sin        53.716298         0.376008          142.860           0.000
# L18.x2cos        80.083823              NAN              NAN             NAN
# L18.x2sin        24.223947              NAN              NAN             NAN
# L18.x3cos       -56.928724         0.885976          -64.255           0.000
# L18.x3sin       -86.893191         0.792923         -109.586           0.000
# L18.x4cos        22.434332              NAN              NAN             NAN
# L18.x4sin       -51.690229              NAN              NAN             NAN
# L19.x0cos        10.921660         0.274534           39.783           0.000
# L19.x1cos       -13.958816              NAN              NAN             NAN
# L19.x1sin       -51.909988              NAN              NAN             NAN
# L19.x2cos       -43.495318              NAN              NAN             NAN
# L19.x2sin        73.378436         0.326988          224.407           0.000
# L19.x3cos        98.615397              NAN              NAN             NAN
# L19.x3sin         4.414112         1.019416            4.330           0.000
# L19.x4cos       -36.286824              NAN              NAN             NAN
# L19.x4sin        38.759641              NAN              NAN             NAN
# L20.x0cos        -9.204640         0.374461          -24.581           0.000
# L20.x1cos        39.122931              NAN              NAN             NAN
# L20.x1sin        33.280842              NAN              NAN             NAN
# L20.x2cos       -82.669926         0.900902          -91.764           0.000
# L20.x2sin       -76.003353              NAN              NAN             NAN
# L20.x3cos       -61.699907              NAN              NAN             NAN
# L20.x3sin        78.369687         0.621791          126.039           0.000
# L20.x4cos        46.783784         0.672248           69.593           0.000
# L20.x4sin       -26.937886              NAN              NAN             NAN
# L21.x0cos         9.946008         0.464312           21.421           0.000
# L21.x1cos       -48.909488              NAN              NAN             NAN
# L21.x1sin        -3.244143              NAN              NAN             NAN
# L21.x2cos       134.701461         0.782540          172.134           0.000
# L21.x2sin       -83.563157              NAN              NAN             NAN
# L21.x3cos       -41.862088              NAN              NAN             NAN
# L21.x3sin       -96.247823              NAN              NAN             NAN
# L21.x4cos       -57.281456         0.874086          -65.533           0.000
# L21.x4sin        10.978455              NAN              NAN             NAN
# L22.x0cos       -10.724883         0.527473          -20.333           0.000
# L22.x1cos        38.843504              NAN              NAN             NAN
# L22.x1sin       -25.864892         0.421137          -61.417           0.000
# L22.x2cos        48.561273              NAN              NAN             NAN
# L22.x2sin       199.906171         0.226667          881.938           0.000
# L22.x3cos       106.455151         0.479071          222.211           0.000
# L22.x3sin        -5.118806         0.735271           -6.962           0.000
# L22.x4cos        63.981545         0.712026           89.858           0.000
# L22.x4sin        13.824059              NAN              NAN             NAN
# L23.x0cos         9.575617         0.499300           19.178           0.000
# L23.x1cos       -14.886275              NAN              NAN             NAN
# L23.x1sin        41.583707              NAN              NAN             NAN
# L23.x2cos      -235.931401         1.280353         -184.271           0.000
# L23.x2sin       -23.677953              NAN              NAN             NAN
# L23.x3cos       -25.200072              NAN              NAN             NAN
# L23.x3sin        96.586729         1.564360           61.742           0.000
# L23.x4cos       -59.024795         0.561899         -105.045           0.000
# L23.x4sin       -42.498984              NAN              NAN             NAN
# L24.x0cos        -8.856476         0.332974          -26.598           0.000
# L24.x1cos       -10.762677              NAN              NAN             NAN
# L24.x1sin       -39.923058              NAN              NAN             NAN
# L24.x2cos       107.830933         1.552775           69.444           0.000
# L24.x2sin      -220.623051         0.924182         -238.723           0.000
# L24.x3cos       -70.157622         1.465012          -47.889           0.000
# L24.x3sin       -46.197786         0.210773         -219.182           0.000
# L24.x4cos        37.572466              NAN              NAN             NAN
# L24.x4sin        64.044628              NAN              NAN             NAN
# L25.x0cos         9.448004              NAN              NAN             NAN
# L25.x1cos        28.550892              NAN              NAN             NAN
# L25.x1sin        25.911815              NAN              NAN             NAN
# L25.x2cos       158.741622              NAN              NAN             NAN
# L25.x2sin       173.307615         1.652034          104.906           0.000
# L25.x3cos        55.676273         1.075716           51.757           0.000
# L25.x3sin       -31.795562         0.202829         -156.761           0.000
# L25.x4cos        -3.924722              NAN              NAN             NAN
# L25.x4sin       -71.349240         0.944853          -75.514           0.000
# L26.x0cos        -8.934366              NAN              NAN             NAN
# L26.x1cos       -35.659524         0.979406          -36.409           0.000
# L26.x1sin        -7.214730              NAN              NAN             NAN
# L26.x2cos      -204.158862              NAN              NAN             NAN
# L26.x2sin        71.000073         0.761617           93.223           0.000
# L26.x3cos       -13.190172              NAN              NAN             NAN
# L26.x3sin        50.174239         0.829230           60.507           0.000
# L26.x4cos       -32.193415         0.668348          -48.169           0.000
# L26.x4sin        63.535568         0.514375          123.520           0.000
# L27.x0cos         5.844251              NAN              NAN             NAN
# L27.x1cos        33.319657         1.179074           28.259           0.000
# L27.x1sin       -10.732001              NAN              NAN             NAN
# L27.x2cos        22.286374         0.284265           78.400           0.000
# L27.x2sin      -198.058231              NAN              NAN             NAN
# L27.x3cos       -24.307135         0.168808         -143.992           0.000
# L27.x3sin       -53.839337              NAN              NAN             NAN
# L27.x4cos        62.193972              NAN              NAN             NAN
# L27.x4sin       -42.515251         0.403754         -105.300           0.000
# L28.x0cos        -0.793905              NAN              NAN             NAN
# L28.x1cos       -23.525195         0.383274          -61.380           0.000
# L28.x1sin        24.621266         1.263527           19.486           0.000
# L28.x2cos       159.185709         0.256075          621.637           0.000
# L28.x2sin       104.125769              NAN              NAN             NAN
# L28.x3cos        73.008589              NAN              NAN             NAN
# L28.x3sin        18.777433         0.590021           31.825           0.000
# L28.x4cos       -78.463892              NAN              NAN             NAN
# L28.x4sin        10.347506              NAN              NAN             NAN
# L29.x0cos        -3.964239         0.141097          -28.096           0.000
# L29.x1cos         8.319602              NAN              NAN             NAN
# L29.x1sin       -31.489251         1.162159          -27.095           0.000
# L29.x2cos      -162.077451              NAN              NAN             NAN
# L29.x2sin        96.955003         0.622102          155.851           0.000
# L29.x3cos       -62.381067         0.791632          -78.801           0.000
# L29.x3sin        60.270286         0.313154          192.462           0.000
# L29.x4cos        73.904426         0.470038          157.231           0.000
# L29.x4sin        27.012653              NAN              NAN             NAN
# L30.x0cos         5.354022         0.378792           14.134           0.000
# L30.x1cos         8.305261         0.786871           10.555           0.000
# L30.x1sin        28.214563              NAN              NAN             NAN
# L30.x2cos       -21.628478              NAN              NAN             NAN
# L30.x2sin      -189.461553         1.223063         -154.907           0.000
# L30.x3cos       -21.634741         0.721717          -29.977           0.000
# L30.x3sin       -85.616166         0.343209         -249.458           0.000
# L30.x4cos       -49.003567         0.579938          -84.498           0.000
# L30.x4sin       -56.885847              NAN              NAN             NAN
# L31.x0cos        -2.470755         0.494350           -4.998           0.000
# L31.x1cos       -19.064579         0.882948          -21.592           0.000
# L31.x1sin       -15.158692              NAN              NAN             NAN
# L31.x2cos       179.220073         1.334081          134.340           0.000
# L31.x2sin        55.373352         0.859845           64.399           0.000
# L31.x3cos        76.393227         0.285877          267.224           0.000
# L31.x3sin        21.403778         0.265222           80.701           0.000
# L31.x4cos        14.658264         0.541348           27.077           0.000
# L31.x4sin        67.324302         0.364472          184.717           0.000
# L32.x0cos        -1.460175         0.519068           -2.813           0.005
# L32.x1cos        18.550731         0.315472           58.803           0.000
# L32.x1sin        -0.417538              NAN              NAN             NAN
# L32.x2cos      -112.503791         1.736771          -64.778           0.000
# L32.x2sin       129.447275              NAN              NAN             NAN
# L32.x3cos       -44.249495         0.164053         -269.726           0.000
# L32.x3sin        43.702750         0.105723          413.372           0.000
# L32.x4cos        15.409133         0.790964           19.481           0.000
# L32.x4sin       -56.785297         0.281877         -201.454           0.000
# L33.x0cos         3.005670         0.455292            6.602           0.000
# L33.x1cos        -9.424046              NAN              NAN             NAN
# L33.x1sin         9.421559              NAN              NAN             NAN
# L33.x2cos       -58.823338         0.646323          -91.012           0.000
# L33.x2sin      -127.355998         0.690987         -184.310           0.000
# L33.x3cos       -11.522959         0.561195          -20.533           0.000
# L33.x3sin       -41.178150         0.481111          -85.590           0.000
# L33.x4cos       -32.614970         0.816454          -39.947           0.000
# L33.x4sin        34.829371         0.395177           88.136           0.000
# L34.x0cos        -2.710130         0.326244           -8.307           0.000
# L34.x1cos        -0.028566              NAN              NAN             NAN
# L34.x1sin        -8.965061         0.448380          -19.994           0.000
# L34.x2cos        98.901832              NAN              NAN             NAN
# L34.x2sin        -0.427937         1.213123           -0.353           0.724
# L34.x3cos        25.851534              NAN              NAN             NAN
# L34.x3sin         5.666340         1.054022            5.376           0.000
# L34.x4cos        34.777618         0.406889           85.472           0.000
# L34.x4sin       -13.276780         0.691432          -19.202           0.000
# L35.x0cos         2.429112         0.184044           13.199           0.000
# L35.x1cos         3.758787              NAN              NAN             NAN
# L35.x1sin         3.702521         0.236150           15.679           0.000
# L35.x2cos       -23.631568         0.460442          -51.324           0.000
# L35.x2sin        51.926194              NAN              NAN             NAN
# L35.x3cos        -9.376662         0.821465          -11.415           0.000
# L35.x3sin        11.388912         0.210895           54.003           0.000
# L35.x4cos       -25.275411              NAN              NAN             NAN
# L35.x4sin        -0.342897         0.593313           -0.578           0.563
# L36.x0cos        -2.061628         0.081713          -25.230           0.000
# L36.x1cos        -2.480932         0.157312          -15.771           0.000
# L36.x1sin         0.080555              NAN              NAN             NAN
# L36.x2cos       -16.303736         0.195077          -83.576           0.000
# L36.x2sin       -18.864627              NAN              NAN             NAN
# L36.x3cos        -2.833738         0.376490           -7.527           0.000
# L36.x3sin        -6.232375         0.318104          -19.592           0.000
# L36.x4cos        12.476265         0.121644          102.564           0.000
# L36.x4sin         4.370676         0.270100           16.182           0.000
# L37.x0cos         1.055188         0.026883           39.251           0.000
# L37.x1cos         0.533119         0.062763            8.494           0.000
# L37.x1sin        -0.636940              NAN              NAN             NAN
# L37.x2cos         7.027110              NAN              NAN             NAN
# L37.x2sin        -2.014131         0.109491          -18.395           0.000
# L37.x3cos         2.281163         0.056798           40.163           0.000
# L37.x3sin         0.023674         0.168541            0.140           0.888
# L37.x4cos        -3.864141         0.090298          -42.793           0.000
# L37.x4sin        -2.719838         0.061771          -44.031           0.000
# L38.x0cos        -0.209249         0.005052          -41.418           0.000
# L38.x1cos         0.022383         0.009041            2.476           0.013
# L38.x1sin         0.143895         0.007251           19.846           0.000
# L38.x2cos        -0.187646              NAN              NAN             NAN
# L38.x2sin         1.059589              NAN              NAN             NAN
# L38.x3cos        -0.178042         0.026956           -6.605           0.000
# L38.x3sin         0.358434         0.013636           26.287           0.000
# L38.x4cos         0.588064         0.018810           31.264           0.000
# L38.x4sin         0.620266         0.009489           65.369           0.000
# ============================================================================
#
# Results for equation x1cos
# ============================================================================
#                coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------
# L1.x0cos         -0.038594         0.004311           -8.952           0.000
# L1.x1cos          5.372446         0.006208          865.390           0.000
# L1.x1sin         -2.938762         0.004106         -715.797           0.000
# L1.x2cos          0.114572         0.017461            6.562           0.000
# L1.x2sin          0.257433         0.009578           26.877           0.000
# L1.x3cos         -0.421227         0.006145          -68.543           0.000
# L1.x3sin          0.009448         0.008186            1.154           0.248
# L1.x4cos          0.303868         0.007106           42.763           0.000
# L1.x4sin         -0.161043         0.014282          -11.276           0.000
# L2.x0cos          0.218236         0.020445           10.674           0.000
# L2.x1cos        -10.252116         0.036142         -283.659           0.000
# L2.x1sin         15.949261         0.021214          751.810           0.000
# L2.x2cos         -1.892401         0.060873          -31.088           0.000
# L2.x2sin          0.301716         0.091273            3.306           0.001
# L2.x3cos          1.213018         0.030234           40.122           0.000
# L2.x3sin         -2.347677         0.040820          -57.512           0.000
# L2.x4cos         -2.003014         0.014361         -139.480           0.000
# L2.x4sin          0.060440         0.083874            0.721           0.471
# L3.x0cos         -0.648804         0.051567          -12.582           0.000
# L3.x1cos          3.130717         0.077924           40.176           0.000
# L3.x1sin        -40.277703         0.085250         -472.465           0.000
# L3.x2cos          1.215700         0.168625            7.209           0.000
# L3.x2sin         -6.406630         0.231183          -27.712           0.000
# L3.x3cos          4.822454         0.131232           36.748           0.000
# L3.x3sin          7.092384              NAN              NAN             NAN
# L3.x4cos          5.248948         0.091561           57.327           0.000
# L3.x4sin          2.445328         0.199538           12.255           0.000
# L4.x0cos          1.444241         0.090400           15.976           0.000
# L4.x1cos         27.011401         0.096531          279.820           0.000
# L4.x1sin         62.023962         0.181896          340.985           0.000
# L4.x2cos         11.940974         0.415894           28.712           0.000
# L4.x2sin          7.821538         0.157052           49.802           0.000
# L4.x3cos        -19.060565              NAN              NAN             NAN
# L4.x3sin          2.050376         0.232974            8.801           0.000
# L4.x4cos         -6.647846         0.333201          -19.951           0.000
# L4.x4sin         -8.802508         0.125730          -70.011           0.000
# L5.x0cos         -2.737964         0.119018          -23.005           0.000
# L5.x1cos        -75.090692         0.106928         -702.253           0.000
# L5.x1sin        -60.015725         0.236366         -253.910           0.000
# L5.x2cos        -18.699247         0.377140          -49.582           0.000
# L5.x2sin         12.532480              NAN              NAN             NAN
# L5.x3cos         11.600354         0.096140          120.661           0.000
# L5.x3sin        -30.759107         0.307781          -99.938           0.000
# L5.x4cos          1.659894         0.578392            2.870           0.004
# L5.x4sin         15.705732              NAN              NAN             NAN
# L6.x0cos          4.447179         0.135087           32.921           0.000
# L6.x1cos        119.777694              NAN              NAN             NAN
# L6.x1sin         22.672647         0.236599           95.827           0.000
# L6.x2cos         -5.956427              NAN              NAN             NAN
# L6.x2sin        -26.120857         0.483095          -54.070           0.000
# L6.x3cos         32.482914         0.504890           64.337           0.000
# L6.x3sin         32.984763              NAN              NAN             NAN
# L6.x4cos          9.532706         0.354392           26.899           0.000
# L6.x4sin        -16.657448              NAN              NAN             NAN
# L7.x0cos         -6.115564         0.148033          -41.312           0.000
# L7.x1cos       -135.939461         0.063322        -2146.787           0.000
# L7.x1sin         42.661583         0.188794          225.969           0.000
# L7.x2cos         23.890411              NAN              NAN             NAN
# L7.x2sin         -0.178632              NAN              NAN             NAN
# L7.x3cos        -52.467147              NAN              NAN             NAN
# L7.x3sin         20.675010         0.470549           43.938           0.000
# L7.x4cos        -20.812267              NAN              NAN             NAN
# L7.x4sin          7.788628         0.470727           16.546           0.000
# L8.x0cos          7.149645         0.128179           55.779           0.000
# L8.x1cos        109.077480         0.205139          531.725           0.000
# L8.x1sin       -112.027374         0.322241         -347.651           0.000
# L8.x2cos          5.326567              NAN              NAN             NAN
# L8.x2sin         18.276567              NAN              NAN             NAN
# L8.x3cos          0.356742         0.467562            0.763           0.445
# L8.x3sin        -61.461709         0.037789        -1626.446           0.000
# L8.x4cos         24.242514              NAN              NAN             NAN
# L8.x4sin          8.534675              NAN              NAN             NAN
# L9.x0cos         -7.140760              NAN              NAN             NAN
# L9.x1cos        -44.435332         0.302526         -146.881           0.000
# L9.x1sin        156.837273         0.505771          310.096           0.000
# L9.x2cos        -22.076843         0.432973          -50.989           0.000
# L9.x2sin         18.948711              NAN              NAN             NAN
# L9.x3cos         57.776927              NAN              NAN             NAN
# L9.x3sin         21.787924         0.474833           45.885           0.000
# L9.x4cos        -15.794944         0.307023          -51.445           0.000
# L9.x4sin        -24.423585              NAN              NAN             NAN
# L10.x0cos         5.895243              NAN              NAN             NAN
# L10.x1cos       -35.702137         0.282980         -126.165           0.000
# L10.x1sin      -159.110592         0.540490         -294.382           0.000
# L10.x2cos       -28.620514         0.161272         -177.467           0.000
# L10.x2sin       -38.898769         0.425573          -91.403           0.000
# L10.x3cos       -37.399059              NAN              NAN             NAN
# L10.x3sin        45.872683         0.250936          182.807           0.000
# L10.x4cos        -2.031153              NAN              NAN             NAN
# L10.x4sin        31.867170              NAN              NAN             NAN
# L11.x0cos        -3.989816              NAN              NAN             NAN
# L11.x1cos       104.307579              NAN              NAN             NAN
# L11.x1sin       118.727920         0.551888          215.130           0.000
# L11.x2cos        61.384979         0.243859          251.723           0.000
# L11.x2sin       -25.066324         0.078778         -318.189           0.000
# L11.x3cos       -30.819642         0.176036         -175.076           0.000
# L11.x3sin       -45.508277              NAN              NAN             NAN
# L11.x4cos        22.619352              NAN              NAN             NAN
# L11.x4sin       -27.098095         0.322570          -84.007           0.000
# L12.x0cos         2.786894              NAN              NAN             NAN
# L12.x1cos      -140.833621              NAN              NAN             NAN
# L12.x1sin       -50.447283         0.286158         -176.292           0.000
# L12.x2cos         7.448481              NAN              NAN             NAN
# L12.x2sin        78.660271         0.283263          277.693           0.000
# L12.x3cos        46.180027         0.186458          247.669           0.000
# L12.x3sin       -17.872582              NAN              NAN             NAN
# L12.x4cos       -37.847881              NAN              NAN             NAN
# L12.x4sin        10.296052         0.223424           46.083           0.000
# L13.x0cos        -2.720120              NAN              NAN             NAN
# L13.x1cos       137.157894              NAN              NAN             NAN
# L13.x1sin       -23.023786              NAN              NAN             NAN
# L13.x2cos       -83.113533         0.401202         -207.162           0.000
# L13.x2sin       -17.726967              NAN              NAN             NAN
# L13.x3cos        11.805719              NAN              NAN             NAN
# L13.x3sin        44.241897         0.218110          202.842           0.000
# L13.x4cos        40.095656              NAN              NAN             NAN
# L13.x4sin        14.451962              NAN              NAN             NAN
# L14.x0cos         2.665330              NAN              NAN             NAN
# L14.x1cos       -99.470094         0.407573         -244.054           0.000
# L14.x1sin        79.701742              NAN              NAN             NAN
# L14.x2cos        42.048164         0.069467          605.296           0.000
# L14.x2sin       -73.736205              NAN              NAN             NAN
# L14.x3cos       -46.542252              NAN              NAN             NAN
# L14.x3sin        10.019875         0.290638           34.475           0.000
# L14.x4cos       -25.451413              NAN              NAN             NAN
# L14.x4sin       -37.435894              NAN              NAN             NAN
# L15.x0cos        -2.092788              NAN              NAN             NAN
# L15.x1cos        43.969758         0.570605           77.058           0.000
# L15.x1sin      -106.849725              NAN              NAN             NAN
# L15.x2cos        53.146132              NAN              NAN             NAN
# L15.x2sin        58.879085              NAN              NAN             NAN
# L15.x3cos        -5.523799         0.508667          -10.859           0.000
# L15.x3sin       -53.332099              NAN              NAN             NAN
# L15.x4cos        -1.794799         0.124927          -14.367           0.000
# L15.x4sin        45.276319         0.248945          181.873           0.000
# L16.x0cos         1.885893              NAN              NAN             NAN
# L16.x1cos        11.720851         0.593528           19.748           0.000
# L16.x1sin       103.356150         0.242779          425.722           0.000
# L16.x2cos       -62.719882              NAN              NAN             NAN
# L16.x2sin        27.562891              NAN              NAN             NAN
# L16.x3cos        59.869440         0.327880          182.596           0.000
# L16.x3sin         5.376257         0.158086           34.009           0.000
# L16.x4cos        27.827306         0.275648          100.952           0.000
# L16.x4sin       -31.518530              NAN              NAN             NAN
# L17.x0cos        -2.294472              NAN              NAN             NAN
# L17.x1cos       -54.141326         0.207984         -260.315           0.000
# L17.x1sin       -75.923991         0.281927         -269.304           0.000
# L17.x2cos        -6.696131              NAN              NAN             NAN
# L17.x2sin       -54.925776         0.121867         -450.703           0.000
# L17.x3cos       -21.853723         0.595322          -36.709           0.000
# L17.x3sin        60.298480              NAN              NAN             NAN
# L17.x4cos       -38.468760              NAN              NAN             NAN
# L17.x4sin         4.347074         0.266313           16.323           0.000
# L18.x0cos         2.237090         0.067505           33.140           0.000
# L18.x1cos        75.169358              NAN              NAN             NAN
# L18.x1sin        35.389035         0.208870          169.431           0.000
# L18.x2cos        43.497206              NAN              NAN             NAN
# L18.x2sin         5.926665              NAN              NAN             NAN
# L18.x3cos       -51.808397         0.492154         -105.269           0.000
# L18.x3sin       -38.423457         0.440464          -87.234           0.000
# L18.x4cos        30.080735              NAN              NAN             NAN
# L18.x4sin        20.894069              NAN              NAN             NAN
# L19.x0cos        -1.162247         0.152502           -7.621           0.000
# L19.x1cos       -73.003013              NAN              NAN             NAN
# L19.x1sin         5.381815              NAN              NAN             NAN
# L19.x2cos       -13.155214              NAN              NAN             NAN
# L19.x2sin        33.416282         0.181640          183.970           0.000
# L19.x3cos        51.142790              NAN              NAN             NAN
# L19.x3sin       -36.533558         0.566279          -64.515           0.000
# L19.x4cos       -10.085395              NAN              NAN             NAN
# L19.x4sin       -33.475584              NAN              NAN             NAN
# L20.x0cos        -0.252381         0.208011           -1.213           0.225
# L20.x1cos        52.992767              NAN              NAN             NAN
# L20.x1sin       -35.102072              NAN              NAN             NAN
# L20.x2cos       -26.080296         0.500445          -52.114           0.000
# L20.x2sin       -18.281244              NAN              NAN             NAN
# L20.x3cos        15.296822              NAN              NAN             NAN
# L20.x3sin        58.286942         0.345401          168.752           0.000
# L20.x4cos       -10.292077         0.373429          -27.561           0.000
# L20.x4sin        31.538373              NAN              NAN             NAN
# L21.x0cos         1.425953         0.257922            5.529           0.000
# L21.x1cos       -25.135843              NAN              NAN             NAN
# L21.x1sin        48.264595              NAN              NAN             NAN
# L21.x2cos        24.322548         0.434696           55.953           0.000
# L21.x2sin       -20.711515              NAN              NAN             NAN
# L21.x3cos       -55.107556              NAN              NAN             NAN
# L21.x3sin        -9.987464              NAN              NAN             NAN
# L21.x4cos        23.557327         0.485549           48.517           0.000
# L21.x4sin       -19.518073              NAN              NAN             NAN
# L22.x0cos        -2.327140         0.293008           -7.942           0.000
# L22.x1cos        -0.903942              NAN              NAN             NAN
# L22.x1sin       -45.982939         0.233939         -196.560           0.000
# L22.x2cos        14.867990              NAN              NAN             NAN
# L22.x2sin        32.845278         0.125912          260.859           0.000
# L22.x3cos        31.646273         0.266121          118.917           0.000
# L22.x3sin       -38.773757         0.408439          -94.932           0.000
# L22.x4cos       -27.431362         0.395526          -69.354           0.000
# L22.x4sin         3.281982              NAN              NAN             NAN
# L23.x0cos         2.904751         0.277358           10.473           0.000
# L23.x1cos        18.880900              NAN              NAN             NAN
# L23.x1sin        33.306067              NAN              NAN             NAN
# L23.x2cos       -44.195093         0.711228          -62.139           0.000
# L23.x2sin         5.293700              NAN              NAN             NAN
# L23.x3cos        13.543037              NAN              NAN             NAN
# L23.x3sin        41.429886         0.868992           47.676           0.000
# L23.x4cos        22.050154         0.312131           70.644           0.000
# L23.x4sin        11.800770              NAN              NAN             NAN
# L24.x0cos        -3.266828         0.184965          -17.662           0.000
# L24.x1cos       -26.220330              NAN              NAN             NAN
# L24.x1sin       -16.770207              NAN              NAN             NAN
# L24.x2cos        12.963042         0.862557           15.029           0.000
# L24.x2sin       -55.495577         0.513377         -108.099           0.000
# L24.x3cos       -36.215975         0.813805          -44.502           0.000
# L24.x3sin       -11.773499         0.117083         -100.557           0.000
# L24.x4cos        -9.930462              NAN              NAN             NAN
# L24.x4sin       -20.878914              NAN              NAN             NAN
# L25.x0cos         3.985834              NAN              NAN             NAN
# L25.x1cos        24.328563              NAN              NAN             NAN
# L25.x1sin         2.820628              NAN              NAN             NAN
# L25.x2cos        57.184924              NAN              NAN             NAN
# L25.x2sin        41.524592         0.917694           45.249           0.000
# L25.x3cos        28.206378         0.597554           47.203           0.000
# L25.x3sin       -19.606435         0.112670         -174.016           0.000
# L25.x4cos        -3.517024              NAN              NAN             NAN
# L25.x4sin        21.661534         0.524860           41.271           0.000
# L26.x0cos        -5.089629              NAN              NAN             NAN
# L26.x1cos       -18.043614         0.544054          -33.165           0.000
# L26.x1sin         5.006929              NAN              NAN             NAN
# L26.x2cos       -71.722201              NAN              NAN             NAN
# L26.x2sin        39.586865         0.423073           93.570           0.000
# L26.x3cos         0.397958              NAN              NAN             NAN
# L26.x3sin        31.708255         0.460632           68.836           0.000
# L26.x4cos        13.503844         0.371263           36.373           0.000
# L26.x4sin       -15.603657         0.285732          -54.609           0.000
# L27.x0cos         5.598584              NAN              NAN             NAN
# L27.x1cos        12.155228         0.654968           18.558           0.000
# L27.x1sin        -7.558476              NAN              NAN             NAN
# L27.x2cos        -2.921320         0.157907          -18.500           0.000
# L27.x2sin       -88.855848              NAN              NAN             NAN
# L27.x3cos       -25.201289         0.093772         -268.751           0.000
# L27.x3sin       -13.289126              NAN              NAN             NAN
# L27.x4cos       -18.519124              NAN              NAN             NAN
# L27.x4sin         6.242314         0.224283           27.832           0.000
# L28.x0cos        -5.103254              NAN              NAN             NAN
# L28.x1cos        -8.524892         0.212906          -40.041           0.000
# L28.x1sin         7.820065         0.701881           11.142           0.000
# L28.x2cos        81.588743         0.142248          573.566           0.000
# L28.x2sin        41.408172              NAN              NAN             NAN
# L28.x3cos        18.102893              NAN              NAN             NAN
# L28.x3sin       -15.500837         0.327753          -47.294           0.000
# L28.x4cos        19.147379              NAN              NAN             NAN
# L28.x4sin         2.746546              NAN              NAN             NAN
# L29.x0cos         4.377238         0.078378           55.848           0.000
# L29.x1cos         6.511422              NAN              NAN             NAN
# L29.x1sin        -8.047860         0.645572          -12.466           0.000
# L29.x2cos       -75.645527              NAN              NAN             NAN
# ...
# L17.x3cos        16.515917         0.309437           53.374           0.000
# L17.x3sin       -88.655302              NAN              NAN             NAN
# L17.x4cos       -13.768502              NAN              NAN             NAN
# L17.x4sin       -23.239167         0.138424         -167.883           0.000
# L18.x0cos         2.851880         0.035088           81.279           0.000
# L18.x1cos         7.674481              NAN              NAN             NAN
# L18.x1sin        -6.407566         0.108567          -59.020           0.000
# L18.x2cos       -22.389850              NAN              NAN             NAN
# L18.x2sin        27.026910              NAN              NAN             NAN
# L18.x3cos        73.207300         0.255812          286.176           0.000
# L18.x3sin        48.792578         0.228945          213.119           0.000
# L18.x4cos         1.189805              NAN              NAN             NAN
# L18.x4sin        21.434750              NAN              NAN             NAN
# L19.x0cos        -2.992096         0.079268          -37.747           0.000
# L19.x1cos        -2.817615              NAN              NAN             NAN
# L19.x1sin         8.662584              NAN              NAN             NAN
# L19.x2cos       -30.491508              NAN              NAN             NAN
# L19.x2sin       -37.785459         0.094413         -400.215           0.000
# L19.x3cos       -69.563623              NAN              NAN             NAN
# L19.x3sin        43.259739         0.294341          146.971           0.000
# L19.x4cos         5.862625              NAN              NAN             NAN
# L19.x4sin       -16.669712              NAN              NAN             NAN
# L20.x0cos         3.057419         0.108120           28.278           0.000
# L20.x1cos        -2.159939              NAN              NAN             NAN
# L20.x1sin        -7.672662              NAN              NAN             NAN
# L20.x2cos        60.986217         0.260122          234.452           0.000
# L20.x2sin       -20.998395              NAN              NAN             NAN
# L20.x3cos        -8.177715              NAN              NAN             NAN
# L20.x3sin       -74.079204         0.179533         -412.622           0.000
# L20.x4cos        -9.141823         0.194102          -47.098           0.000
# L20.x4sin        11.044369              NAN              NAN             NAN
# L21.x0cos        -2.644013         0.134063          -19.722           0.000
# L21.x1cos         5.189477              NAN              NAN             NAN
# L21.x1sin         4.395189              NAN              NAN             NAN
# L21.x2cos        -5.198899         0.225947          -23.009           0.000
# L21.x2sin        80.847434              NAN              NAN             NAN
# L21.x3cos        63.451443              NAN              NAN             NAN
# L21.x3sin        22.536121              NAN              NAN             NAN
# L21.x4cos        10.115696         0.252379           40.081           0.000
# L21.x4sin        -6.066138              NAN              NAN             NAN
# L22.x0cos         1.559283         0.152300           10.238           0.000
# L22.x1cos        -5.769517              NAN              NAN             NAN
# L22.x1sin        -0.878794         0.121597           -7.227           0.000
# L22.x2cos       -85.773191              NAN              NAN             NAN
# L22.x2sin       -42.511503         0.065447         -649.559           0.000
# L22.x3cos       -41.554813         0.138325         -300.415           0.000
# L22.x3sin        42.602252         0.212299          200.671           0.000
# L22.x4cos       -10.613594         0.205587          -51.626           0.000
# L22.x4sin         2.758938              NAN              NAN             NAN
# L23.x0cos        -0.487497         0.144165           -3.382           0.001
# L23.x1cos         5.002231              NAN              NAN             NAN
# L23.x1sin        -1.771831              NAN              NAN             NAN
# L23.x2cos        78.897599         0.369683          213.420           0.000
# L23.x2sin       -69.995901              NAN              NAN             NAN
# L23.x3cos       -19.417078              NAN              NAN             NAN
# L23.x3sin       -45.314189         0.451686         -100.322           0.000
# L23.x4cos        11.468579         0.162240           70.689           0.000
# L23.x4sin        -0.739552              NAN              NAN             NAN
# L24.x0cos         0.531347         0.096141            5.527           0.000
# L24.x1cos        -3.579064              NAN              NAN             NAN
# L24.x1sin         3.822113              NAN              NAN             NAN
# L24.x2cos        36.045470         0.448341           80.398           0.000
# L24.x2sin       101.221430         0.266844          379.329           0.000
# L24.x3cos        36.240476         0.423000           85.675           0.000
# L24.x3sin        -2.169004         0.060858          -35.641           0.000
# L24.x4cos       -11.831497              NAN              NAN             NAN
# L24.x4sin        -1.398053              NAN              NAN             NAN
# L25.x0cos        -1.192426              NAN              NAN             NAN
# L25.x1cos         1.274848              NAN              NAN             NAN
# L25.x1sin        -5.193532              NAN              NAN             NAN
# L25.x2cos      -100.309166              NAN              NAN             NAN
# L25.x2sin        -5.561803         0.477000          -11.660           0.000
# L25.x3cos        -4.967123         0.310597          -15.992           0.000
# L25.x3sin        21.579474         0.058564          368.478           0.000
# L25.x4cos        10.910006              NAN              NAN             NAN
# L25.x4sin         4.769637         0.272812           17.483           0.000
# L26.x0cos         1.070809              NAN              NAN             NAN
# L26.x1cos         1.508942         0.282789            5.336           0.000
# L26.x1sin         5.075380              NAN              NAN             NAN
# L26.x2cos        39.766803              NAN              NAN             NAN
# L26.x2sin       -75.959533         0.219905         -345.419           0.000
# L26.x3cos        -8.345446              NAN              NAN             NAN
# L26.x3sin        -3.340808         0.239428          -13.953           0.000
# L26.x4cos        -8.485150         0.192975          -43.970           0.000
# L26.x4sin        -8.938381         0.148518          -60.184           0.000
# L27.x0cos        -0.058426              NAN              NAN             NAN
# L27.x1cos        -3.496142         0.340440          -10.269           0.000
# L27.x1sin        -3.438308              NAN              NAN             NAN
# L27.x2cos        38.347165         0.082077          467.209           0.000
# L27.x2sin        54.510786              NAN              NAN             NAN
# L27.x3cos        -3.296371         0.048741          -67.630           0.000
# L27.x3sin        -0.215570              NAN              NAN             NAN
# L27.x4cos         4.316030              NAN              NAN             NAN
# L27.x4sin        12.451454         0.116578          106.808           0.000
# L28.x0cos        -1.075611              NAN              NAN             NAN
# L28.x1cos         4.038239         0.110665           36.491           0.000
# L28.x1sin         1.333152         0.364825            3.654           0.000
# L28.x2cos       -47.338751         0.073938         -640.250           0.000
# L28.x2sin         2.646522              NAN              NAN             NAN
# L28.x3cos        -1.683476              NAN              NAN             NAN
# L28.x3sin       -11.230004         0.170360          -65.919           0.000
# L28.x4cos         1.728103              NAN              NAN             NAN
# L28.x4sin       -14.162839              NAN              NAN             NAN
# L29.x0cos         2.007165         0.040740           49.268           0.000
# L29.x1cos        -3.470400              NAN              NAN             NAN
# L29.x1sin         0.326113         0.335556            0.972           0.331
# L29.x2cos        19.099304              NAN              NAN             NAN
# L29.x2sin       -25.563339         0.179623         -142.317           0.000
# L29.x3cos        16.969206         0.228572           74.240           0.000
# L29.x3sin         1.804759         0.090418           19.960           0.000
# L29.x4cos        -9.034888         0.135716          -66.572           0.000
# L29.x4sin        13.002667              NAN              NAN             NAN
# L30.x0cos        -2.636054         0.109371          -24.102           0.000
# L30.x1cos         2.372804         0.227197           10.444           0.000
# L30.x1sin        -1.076881              NAN              NAN             NAN
# L30.x2cos         1.167844              NAN              NAN             NAN
# L30.x2sin        23.057393         0.353141           65.292           0.000
# L30.x3cos        -7.574856         0.208385          -36.350           0.000
# L30.x3sin        18.379756         0.099096          185.473           0.000
# L30.x4cos        15.560771         0.167448           92.929           0.000
# L30.x4sin        -7.791415              NAN              NAN             NAN
# L31.x0cos         2.625749         0.142736           18.396           0.000
# L31.x1cos        -1.514378         0.254938           -5.940           0.000
# L31.x1sin         0.808912              NAN              NAN             NAN
# L31.x2cos       -13.561792         0.385196          -35.208           0.000
# L31.x2sin       -15.727697         0.248268          -63.350           0.000
# L31.x3cos       -16.071628         0.082543         -194.707           0.000
# L31.x3sin       -12.259791         0.076579         -160.093           0.000
# L31.x4cos       -18.136637         0.156306         -116.033           0.000
# L31.x4sin        -0.833629         0.105236           -7.922           0.000
# L32.x0cos        -1.938451         0.149873          -12.934           0.000
# L32.x1cos         1.474658         0.091088           16.189           0.000
# L32.x1sin        -0.185147              NAN              NAN             NAN
# L32.x2cos        20.532373         0.501467           40.945           0.000
# L32.x2sin         1.030042              NAN              NAN             NAN
# L32.x3cos        14.364650         0.047368          303.257           0.000
# L32.x3sin       -11.878454         0.030526         -389.128           0.000
# L32.x4cos        14.821505         0.228379           64.899           0.000
# L32.x4sin         9.235860         0.081388          113.480           0.000
# L33.x0cos         1.136326         0.131459            8.644           0.000
# L33.x1cos        -1.866304              NAN              NAN             NAN
# L33.x1sin         0.062525              NAN              NAN             NAN
# L33.x2cos       -11.971436         0.186616          -64.150           0.000
# L33.x2sin        14.486547         0.199512           72.610           0.000
# L33.x3cos         7.352079         0.162037           45.373           0.000
# L33.x3sin        13.916152         0.138914          100.178           0.000
# L33.x4cos        -7.067120         0.235739          -29.979           0.000
# L33.x4sin       -13.299231         0.114101         -116.556           0.000
# L34.x0cos        -0.584455         0.094198           -6.205           0.000
# L34.x1cos         1.880749              NAN              NAN             NAN
# L34.x1sin        -0.468196         0.129463           -3.616           0.000
# L34.x2cos        -4.363209              NAN              NAN             NAN
# L34.x2sin       -13.949621         0.350271          -39.825           0.000
# L34.x3cos       -11.726006              NAN              NAN             NAN
# L34.x3sin         3.185157         0.304333           10.466           0.000
# L34.x4cos        -0.808117         0.117483           -6.879           0.000
# L34.x4sin        11.679306         0.199641           58.502           0.000
# L35.x0cos         0.178030         0.053140            3.350           0.001
# L35.x1cos        -1.286353              NAN              NAN             NAN
# L35.x1sin         0.829148         0.068185           12.160           0.000
# L35.x2cos         8.897362         0.132946           66.925           0.000
# L35.x2sin         2.207535              NAN              NAN             NAN
# L35.x3cos         0.258871         0.237186            1.091           0.275
# L35.x3sin        -8.047521         0.060893         -132.159           0.000
# L35.x4cos         4.709572              NAN              NAN             NAN
# L35.x4sin        -6.618984         0.171310          -38.637           0.000
# L36.x0cos         0.089839         0.023594            3.808           0.000
# L36.x1cos         0.501413         0.045422           11.039           0.000
# L36.x1sin        -0.740397              NAN              NAN             NAN
# L36.x2cos        -3.033764         0.056326          -53.861           0.000
# L36.x2sin         3.029522              NAN              NAN             NAN
# L36.x3cos         3.700767         0.108706           34.044           0.000
# L36.x3sin         1.638711         0.091848           17.842           0.000
# L36.x4cos        -4.090907         0.035123         -116.474           0.000
# L36.x4sin         2.001016         0.077987           25.658           0.000
# L37.x0cos        -0.120210         0.007762          -15.487           0.000
# L37.x1cos        -0.046882         0.018122           -2.587           0.010
# L37.x1sin         0.343900              NAN              NAN             NAN
# L37.x2cos        -0.292826              NAN              NAN             NAN
# L37.x2sin        -1.259594         0.031614          -39.843           0.000
# L37.x3cos        -1.016486         0.016399          -61.983           0.000
# L37.x3sin         0.870413         0.048664           17.886           0.000
# L37.x4cos         1.756628         0.026072           67.375           0.000
# L37.x4sin        -0.018727         0.017836           -1.050           0.294
# L38.x0cos         0.036980         0.001459           25.350           0.000
# L38.x1cos        -0.022886         0.002610           -8.767           0.000
# L38.x1sin        -0.061779         0.002094          -29.510           0.000
# L38.x2cos         0.174192              NAN              NAN             NAN
# L38.x2sin         0.060763              NAN              NAN             NAN
# L38.x3cos        -0.044581         0.007783           -5.728           0.000
# L38.x3sin        -0.214974         0.003937          -54.602           0.000
# L38.x4cos        -0.315748         0.005431          -58.138           0.000
# L38.x4sin        -0.124798         0.002740          -45.552           0.000
# ============================================================================
#
# Correlation matrix of residuals
#             x0cos     x1cos     x1sin     x2cos     x2sin     x3cos     x3sin     x4cos     x4sin
# x0cos    1.000000  0.025590  0.182544 -0.068662  0.035086 -0.145918  0.140562 -0.169386 -0.655654
# x1cos    0.025590  1.000000 -0.040928  0.168042  0.096258 -0.071506  0.183317 -0.026271 -0.049782
# x1sin    0.182544 -0.040928  1.000000 -0.085712  0.090704 -0.229392  0.087693 -0.129162 -0.122350
# x2cos   -0.068662  0.168042 -0.085712  1.000000  0.107004  0.000711 -0.095880  0.053014 -0.027168
# x2sin    0.035086  0.096258  0.090704  0.107004  1.000000  0.050217 -0.067604 -0.011417 -0.063163
# x3cos   -0.145918 -0.071506 -0.229392  0.000711  0.050217  1.000000 -0.252884 -0.050126  0.041953
# x3sin    0.140562  0.183317  0.087693 -0.095880 -0.067604 -0.252884  1.000000  0.012119 -0.167131
# x4cos   -0.169386 -0.026271 -0.129162  0.053014 -0.011417 -0.050126  0.012119  1.000000  0.146153
# x4sin   -0.655654 -0.049782 -0.122350 -0.027168 -0.063163  0.041953 -0.167131  0.146153  1.000000

# %%
# Wald Test
causal_results = results.test_causality('x0cos', 'x1cos', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0cos', 'x1sin', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0cos', 'x2cos', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0cos', 'x2sin', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0cos', 'x3cos', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0cos', 'x3sin', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0cos', 'x4cos', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0cos', 'x4sin', kind='Wald')
print(causal_results.summary())
# Out:
# Granger causality Wald-test. H_0: x1cos does not Granger-cause x0cos. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   5.164e+04        53.38       0.000  38
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x1sin does not Granger-cause x0cos. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#     -490.5         53.38       1.000  38
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x2cos does not Granger-cause x0cos. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   1.296e+05        53.38       0.000  38
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x2sin does not Granger-cause x0cos. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   6.450e+05        53.38       0.000  38
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x3cos does not Granger-cause x0cos. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   -6.148e+04       53.38       1.000  38
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x3sin does not Granger-cause x0cos. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   -2.055e+04       53.38       1.000  38
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x4cos does not Granger-cause x0cos. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   -3.915e+04       53.38       1.000  38
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x4sin does not Granger-cause x0cos. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   1.973e+04        53.38       0.000  38
# ----------------------------------------

# %%
kuramoto_df_wo_x0cos=kuramoto_df.drop(columns=['x0cos'])
model = VAR(kuramoto_df_wo_x0cos)
#find optimal lag order by information criteria
lag_orders_data = model.select_order(trend='nc')
print(lag_orders_data.selected_orders)
# Out:
# {'aic': 38, 'bic': 38, 'hqic': 38, 'fpe': 38}

# %%
results = model.fit(lag_orders_data.selected_orders['bic'],trend='nc')

# %%
# Wald Test
causal_results = results.test_causality('x0sin', 'x1cos', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0sin', 'x1sin', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0sin', 'x2cos', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0sin', 'x2sin', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0sin', 'x3cos', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0sin', 'x3sin', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0sin', 'x4cos', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0sin', 'x4sin', kind='Wald')
print(causal_results.summary())
# Out:
# Granger causality Wald-test. H_0: x1cos does not Granger-cause x0sin. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   -2.016e+04       53.38       1.000  38
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x1sin does not Granger-cause x0sin. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   -5.100e+04       53.38       1.000  38
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x2cos does not Granger-cause x0sin. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   -7.319e+05       53.38       1.000  38
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x2sin does not Granger-cause x0sin. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   -5.571e+05       53.38       1.000  38
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x3cos does not Granger-cause x0sin. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   -2.144e+05       53.38       1.000  38
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x3sin does not Granger-cause x0sin. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   5.994e+05        53.38       0.000  38
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x4cos does not Granger-cause x0sin. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   -1.450e+05       53.38       1.000  38
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x4sin does not Granger-cause x0sin. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   3.064e+04        53.38       0.000  38
# ----------------------------------------

# %% [markdown]
# # Weak Coupling

# %%
# these are our constants
N = 5  # number of variables
K = 0.01 #coupling
omega =  np.array([ 2.31246433, 35.50794494, 53.41350736, 50.23353682,  5.63392492])  # natural frequency
theta0 = np.array([117.35002435, 261.94283291, 260.06912657, 293.69995793,235.11319532]) # initial state 
tinit = 0.0
tmax = 100.0
dt =  0.01

# %%
kuramoto = Kuramoto(N,K,omega)
sol = kuramoto.integrate(tinit, 20, dt, theta0)
kuramoto.evolution_plot()
kuramoto.trajectory_plot()

# %%
kuramoto = Kuramoto(N,K,omega)
sol = kuramoto.integrate(tinit, tmax, dt, theta0)
kuramoto.evolution_plot()
kuramoto.trajectory_plot()

# %%
kuramoto_df = pd.DataFrame(data= sol[1],    
                columns=['x0','x1','x2','x3','x4'])
kuramoto_df = kuramoto_df.transform([np.cos,np.sin])
kuramoto_df.columns = [''.join(col).strip() for col in kuramoto_df.columns.values]

# %%
kuramoto_df_wo_x0sin=kuramoto_df.drop(columns=['x0sin'])
model = VAR(kuramoto_df_wo_x0sin)
#find optimal lag order by information criteria
lag_orders_data = model.select_order(trend='nc')
print(lag_orders_data.selected_orders)
# Out:
# {'aic': 37, 'bic': 37, 'hqic': 37, 'fpe': 37}

# %%
results = model.fit(lag_orders_data.selected_orders['bic'],trend='nc')
print(results.summary())
# Out:
# /usr/local/lib/python3.6/site-packages/statsmodels/tsa/vector_ar/var_model.py:1387: RuntimeWarning: invalid value encountered in sqrt
#   stderr = np.sqrt(np.diag(self.cov_params))
# /usr/local/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /usr/local/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /usr/local/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 06, Jun, 2019
# Time:                     23:36:12
# --------------------------------------------------------------------
# No. of Equations:         9.00000    BIC:                   -482.997
# Nobs:                     9964.00    HQIC:                  -484.431
# Log likelihood:       2.29284e+06    FPE:               1.97614e-211
# AIC:                     -485.165    Det(Omega_mle):    1.47002e-211
# --------------------------------------------------------------------
# Results for equation x0cos
# ============================================================================
#                coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------
# L1.x0cos          8.717621         0.000001      8879946.072           0.000
# L1.x1cos         -0.322564         0.000001      -249333.840           0.000
# L1.x1sin          0.110520         0.000004        28143.328           0.000
# L1.x2cos         -0.096347              NAN              NAN             NAN
# L1.x2sin         -0.310474              NAN              NAN             NAN
# L1.x3cos          0.042429              NAN              NAN             NAN
# L1.x3sin          0.074336         0.000000       370785.813           0.000
# L1.x4cos         -0.424334              NAN              NAN             NAN
# L1.x4sin          0.106099              NAN              NAN             NAN
# L2.x0cos        -34.832001         0.000004     -9177210.830           0.000
# L2.x1cos          1.235210         0.000001      1227840.977           0.000
# L2.x1sin         -1.174728              NAN              NAN             NAN
# L2.x2cos          1.470143         0.000001      1018531.050           0.000
# L2.x2sin          0.644791         0.000000      2096185.069           0.000
# L2.x3cos         -0.420219              NAN              NAN             NAN
# L2.x3sin         -0.172290              NAN              NAN             NAN
# L2.x4cos          2.289880         0.000002      1117490.518           0.000
# L2.x4sin         -0.104753              NAN              NAN             NAN
# L3.x0cos         82.475954         0.000002     54228328.782           0.000
# L3.x1cos         -1.024460              NAN              NAN             NAN
# L3.x1sin          2.722812              NAN              NAN             NAN
# L3.x2cos         -2.322744              NAN              NAN             NAN
# L3.x2sin          1.258935              NAN              NAN             NAN
# L3.x3cos          0.875917              NAN              NAN             NAN
# L3.x3sin         -0.248809         0.000002      -117830.430           0.000
# L3.x4cos         -4.319152              NAN              NAN             NAN
# L3.x4sin         -0.858514         0.000004      -201097.939           0.000
# L4.x0cos       -123.270522         0.000004    -34494542.726           0.000
# L4.x1cos         -0.346948              NAN              NAN             NAN
# L4.x1sin         -1.032159         0.000003      -340338.543           0.000
# L4.x2cos         -0.269889              NAN              NAN             NAN
# L4.x2sin         -0.761741         0.000003      -232714.770           0.000
# L4.x3cos         -0.392749              NAN              NAN             NAN
# L4.x3sin          0.661901              NAN              NAN             NAN
# L4.x4cos          2.362784              NAN              NAN             NAN
# L4.x4sin          1.943939              NAN              NAN             NAN
# L5.x0cos        109.432112         0.000001    114402637.588           0.000
# L5.x1cos         -0.390125         0.000005       -83354.448           0.000
# L5.x1sin         -1.917064              NAN              NAN             NAN
# L5.x2cos         -1.095820              NAN              NAN             NAN
# L5.x2sin         -1.852397         0.000003      -699612.084           0.000
# L5.x3cos         -0.365504         0.000002      -189484.144           0.000
# L5.x3sin         -0.188256         0.000000      -471670.599           0.000
# L5.x4cos          2.028999              NAN              NAN             NAN
# L5.x4sin         -1.162925         0.000001      -849620.517           0.000
# L6.x0cos        -34.377944         0.000001    -24937123.325           0.000
# L6.x1cos          0.230536         0.000003        68207.812           0.000
# L6.x1sin          0.512562         0.000005       111754.627           0.000
# L6.x2cos          0.550575              NAN              NAN             NAN
# L6.x2sin         -1.029020              NAN              NAN             NAN
# L6.x3cos          0.605991              NAN              NAN             NAN
# L6.x3sin         -0.212711         0.000001      -154921.395           0.000
# L6.x4cos         -1.716683         0.000001     -1780668.626           0.000
# L6.x4sin          0.602832         0.000002       323969.389           0.000
# L7.x0cos        -36.779808         0.000002    -23562810.651           0.000
# L7.x1cos          1.730441              NAN              NAN             NAN
# L7.x1sin          0.946891              NAN              NAN             NAN
# L7.x2cos          2.374697         0.000003       894700.205           0.000
# L7.x2sin         -1.029666              NAN              NAN             NAN
# L7.x3cos         -0.452817         0.000002      -241839.102           0.000
# L7.x3sin          0.020120         0.000001        17897.542           0.000
# L7.x4cos         -1.815431         0.000002      -831743.873           0.000
# L7.x4sin         -1.551490              NAN              NAN             NAN
# L8.x0cos         36.995050         0.000002     18489600.790           0.000
# L8.x1cos          0.160207              NAN              NAN             NAN
# L8.x1sin         -0.937374              NAN              NAN             NAN
# L8.x2cos          0.803594         0.000001      1246667.367           0.000
# L8.x2sin          0.239956         0.000004        58445.679           0.000
# L8.x3cos          0.200214         0.000001       148387.922           0.000
# L8.x3sin          0.649045              NAN              NAN             NAN
# L8.x4cos          2.220204              NAN              NAN             NAN
# L8.x4sin         -0.377972         0.000002      -202250.523           0.000
# L9.x0cos         14.082016         0.000001     15553463.231           0.000
# L9.x1cos         -0.908852         0.000007      -131725.489           0.000
# L9.x1sin          1.041429         0.000010       103148.324           0.000
# L9.x2cos          1.266697              NAN              NAN             NAN
# L9.x2sin          0.985132              NAN              NAN             NAN
# L9.x3cos         -0.167691              NAN              NAN             NAN
# L9.x3sin         -0.514109              NAN              NAN             NAN
# L9.x4cos         -0.796064         0.000003      -274325.618           0.000
# L9.x4sin          3.325049         0.000003      1059800.624           0.000
# L10.x0cos       -38.708543         0.000003    -12766746.316           0.000
# L10.x1cos        -0.406064              NAN              NAN             NAN
# L10.x1sin         1.552548              NAN              NAN             NAN
# L10.x2cos         1.265478              NAN              NAN             NAN
# L10.x2sin         1.171347         0.000001       944692.075           0.000
# L10.x3cos        -0.461923         0.000001      -369542.493           0.000
# L10.x3sin        -0.186437         0.000002       -93452.346           0.000
# L10.x4cos        -1.616900         0.000006      -265395.918           0.000
# L10.x4sin        -1.780488         0.000007      -250285.714           0.000
# L11.x0cos        10.818782         0.000001      9298814.560           0.000
# L11.x1cos        -0.464284         0.000003      -145423.405           0.000
# L11.x1sin        -0.406554         0.000005       -77517.578           0.000
# L11.x2cos         0.087259              NAN              NAN             NAN
# L11.x2sin         1.188613         0.000001      1303989.130           0.000
# L11.x3cos         0.666181              NAN              NAN             NAN
# L11.x3sin         0.084228              NAN              NAN             NAN
# L11.x4cos         5.202729         0.000000     21213340.321           0.000
# L11.x4sin         0.490240         0.000000      2310571.027           0.000
# L12.x0cos        18.745802         0.000000     61526591.040           0.000
# L12.x1cos        -0.311985              NAN              NAN             NAN
# L12.x1sin        -2.160023         0.000003      -728883.512           0.000
# L12.x2cos        -0.165475              NAN              NAN             NAN
# L12.x2sin         2.138527              NAN              NAN             NAN
# L12.x3cos        -0.225523              NAN              NAN             NAN
# L12.x3sin         0.540932         0.000001       495097.623           0.000
# L12.x4cos        -4.064279         0.000001     -5357346.361           0.000
# L12.x4sin        -1.308113              NAN              NAN             NAN
# L13.x0cos        -9.513858         0.000003     -3135810.470           0.000
# L13.x1cos        -1.048385         0.000002      -558281.416           0.000
# L13.x1sin         0.005146         0.000005         1113.087           0.000
# L13.x2cos        -1.222178         0.000002      -643771.491           0.000
# L13.x2sin         1.518144              NAN              NAN             NAN
# L13.x3cos        -0.523172         0.000001      -351394.909           0.000
# L13.x3sin        -0.964621         0.000001      -982199.926           0.000
# L13.x4cos        -1.207178              NAN              NAN             NAN
# L13.x4sin        -0.561153              NAN              NAN             NAN
# L14.x0cos       -14.146778              NAN              NAN             NAN
# L14.x1cos         1.603064         0.000001      1122151.593           0.000
# L14.x1sin        -0.185818         0.000008       -23558.734           0.000
# L14.x2cos        -1.404688              NAN              NAN             NAN
# L14.x2sin         0.609829              NAN              NAN             NAN
# L14.x3cos         0.123319              NAN              NAN             NAN
# L14.x3sin         0.136960         0.000002        78045.655           0.000
# L14.x4cos         3.014677              NAN              NAN             NAN
# L14.x4sin         0.945695         0.000002       427058.370           0.000
# L15.x0cos        13.784843         0.000001     18151827.600           0.000
# L15.x1cos         1.171978              NAN              NAN             NAN
# L15.x1sin        -0.079628         0.000002       -34451.566           0.000
# L15.x2cos        -1.577460              NAN              NAN             NAN
# L15.x2sin         0.252895              NAN              NAN             NAN
# L15.x3cos         0.775596              NAN              NAN             NAN
# L15.x3sin        -0.282413              NAN              NAN             NAN
# L15.x4cos        -0.497473              NAN              NAN             NAN
# L15.x4sin         1.540440              NAN              NAN             NAN
# L16.x0cos         4.970329         0.000002      2395729.393           0.000
# L16.x1cos         0.948332         0.000004       216398.478           0.000
# L16.x1sin         0.127851              NAN              NAN             NAN
# L16.x2cos        -2.314160              NAN              NAN             NAN
# L16.x2sin         0.227547              NAN              NAN             NAN
# L16.x3cos         0.466127              NAN              NAN             NAN
# L16.x3sin         0.349009         0.000001       350651.084           0.000
# L16.x4cos        -2.874859              NAN              NAN             NAN
# L16.x4sin        -0.380877              NAN              NAN             NAN
# L17.x0cos       -12.292364              NAN              NAN             NAN
# L17.x1cos        -1.387828         0.000004      -339634.345           0.000
# L17.x1sin         0.988994         0.000004       250192.496           0.000
# L17.x2cos        -1.153636              NAN              NAN             NAN
# L17.x2sin        -1.055056              NAN              NAN             NAN
# L17.x3cos        -1.188204         0.000000     -2692074.354           0.000
# L17.x3sin         0.507337              NAN              NAN             NAN
# L17.x4cos         3.280531              NAN              NAN             NAN
# L17.x4sin        -1.827462         0.000001     -2442653.906           0.000
# L18.x0cos         2.542917         0.000001      4813553.670           0.000
# L18.x1cos         0.201317              NAN              NAN             NAN
# L18.x1sin         1.474073              NAN              NAN             NAN
# L18.x2cos        -1.409980              NAN              NAN             NAN
# L18.x2sin        -2.145494              NAN              NAN             NAN
# L18.x3cos         0.326493         0.000002       186698.305           0.000
# L18.x3sin        -0.483084              NAN              NAN             NAN
# L18.x4cos        -0.898833              NAN              NAN             NAN
# L18.x4sin         0.475724         0.000001       444724.261           0.000
# L19.x0cos         4.798430         0.000001      3922460.619           0.000
# L19.x1cos        -0.432025              NAN              NAN             NAN
# L19.x1sin         0.146487         0.000004        34758.008           0.000
# L19.x2cos        -0.981149         0.000003      -311756.039           0.000
# L19.x2sin        -1.422388         0.000006      -220789.559           0.000
# L19.x3cos         0.643047              NAN              NAN             NAN
# L19.x3sin        -0.428598         0.000001      -390791.848           0.000
# L19.x4cos         0.423080              NAN              NAN             NAN
# L19.x4sin         2.497300              NAN              NAN             NAN
# L20.x0cos         0.985214              NAN              NAN             NAN
# L20.x1cos        -0.703363         0.000000     -1583737.599           0.000
# L20.x1sin        -1.083310              NAN              NAN             NAN
# L20.x2cos         0.778819              NAN              NAN             NAN
# L20.x2sin        -1.864120         0.000002      -759190.820           0.000
# L20.x3cos        -0.087647         0.000001      -135378.333           0.000
# L20.x3sin         0.358128         0.000002       178155.061           0.000
# L20.x4cos         0.258654         0.000001       230397.747           0.000
# L20.x4sin        -4.612796              NAN              NAN             NAN
# L21.x0cos        -8.840210              NAN              NAN             NAN
# L21.x1cos        -1.912269         0.000002      -840400.806           0.000
# L21.x1sin        -0.877170              NAN              NAN             NAN
# L21.x2cos         1.344507         0.000001      1087537.334           0.000
# L21.x2sin        -2.248965         0.000005      -437161.579           0.000
# L21.x3cos         0.003827         0.000000        10572.184           0.000
# L21.x3sin         0.562510         0.000001       385149.650           0.000
# L21.x4cos        -1.445022         0.000001     -1493656.013           0.000
# L21.x4sin         2.983632         0.000005       568281.275           0.000
# L22.x0cos         5.323617         0.000004      1518657.242           0.000
# L22.x1cos         0.760246              NAN              NAN             NAN
# L22.x1sin        -0.295053         0.000003       -89132.452           0.000
# L22.x2cos         0.201282         0.000001       185774.261           0.000
# L22.x2sin        -0.831617         0.000000     -2711371.182           0.000
# L22.x3cos         0.386569         0.000002       165759.816           0.000
# L22.x3sin         0.124104         0.000004        34990.807           0.000
# L22.x4cos        -2.325633              NAN              NAN             NAN
# L22.x4sin         0.576143         0.000001       498723.870           0.000
# L23.x0cos         5.706664              NAN              NAN             NAN
# L23.x1cos         2.138536              NAN              NAN             NAN
# L23.x1sin        -1.027159              NAN              NAN             NAN
# L23.x2cos         2.357122         0.000002       999273.690           0.000
# L23.x2sin        -0.060064         0.000002       -27441.301           0.000
# L23.x3cos        -0.540963         0.000002      -357645.624           0.000
# L23.x3sin        -0.121116         0.000002       -56113.950           0.000
# L23.x4cos         3.920727         0.000001      2625919.971           0.000
# L23.x4sin        -1.941655         0.000002      -829454.452           0.000
# L24.x0cos        -8.689278              NAN              NAN             NAN
# L24.x1cos         0.783301         0.000002       365817.200           0.000
# L24.x1sin        -0.021265              NAN              NAN             NAN
# L24.x2cos         2.223222         0.000005       451701.218           0.000
# L24.x2sin        -1.045095              NAN              NAN             NAN
# L24.x3cos        -0.279938         0.000003      -103690.372           0.000
# L24.x3sin         0.544963         0.000002       261799.862           0.000
# L24.x4cos         1.054561         0.000004       278315.238           0.000
# L24.x4sin         1.759299              NAN              NAN             NAN
# L25.x0cos        -0.985852         0.000004      -269522.815           0.000
# L25.x1cos        -0.369277              NAN              NAN             NAN
# L25.x1sin         1.085853              NAN              NAN             NAN
# L25.x2cos         0.554469         0.000003       163669.782           0.000
# L25.x2sin         0.945214              NAN              NAN             NAN
# L25.x3cos         0.042416         0.000001        71930.479           0.000
# L25.x3sin         0.396828              NAN              NAN             NAN
# L25.x4cos        -1.519532              NAN              NAN             NAN
# L25.x4sin         2.231496              NAN              NAN             NAN
# L26.x0cos         8.877022         0.000001      6664860.126           0.000
# L26.x1cos         0.006183         0.000005         1313.592           0.000
# L26.x1sin         1.861435         0.000002       922481.108           0.000
# L26.x2cos         1.650921              NAN              NAN             NAN
# L26.x2sin         1.938411         0.000001      2044754.991           0.000
# L26.x3cos        -1.016243         0.000002      -502240.312           0.000
# L26.x3sin        -0.834424              NAN              NAN             NAN
# L26.x4cos        -2.058644         0.000004      -545555.085           0.000
# L26.x4sin        -7.201517         0.000001     -8107009.907           0.000
# L27.x0cos        -2.167262              NAN              NAN             NAN
# L27.x1cos        -0.202313              NAN              NAN             NAN
# L27.x1sin         0.253623              NAN              NAN             NAN
# L27.x2cos         1.186185         0.000003       365150.350           0.000
# L27.x2sin         0.578363         0.000001      1089621.560           0.000
# L27.x3cos        -0.409493         0.000002      -257401.176           0.000
# L27.x3sin        -0.551273         0.000002      -364321.782           0.000
# L27.x4cos         1.624975         0.000004       427195.415           0.000
# L27.x4sin         2.402214              NAN              NAN             NAN
# L28.x0cos       -10.335324              NAN              NAN             NAN
# L28.x1cos        -1.593235              NAN              NAN             NAN
# L28.x1sin        -1.176669         0.000009      -137367.633           0.000
# L28.x2cos        -0.659857              NAN              NAN             NAN
# L28.x2sin         1.241497         0.000002       695603.385           0.000
# L28.x3cos         1.128681              NAN              NAN             NAN
# L28.x3sin        -0.426431         0.000001      -474235.933           0.000
# L28.x4cos        -0.656234         0.000002      -279243.782           0.000
# L28.x4sin         5.783814         0.000003      1904615.269           0.000
# L29.x0cos        10.908293         0.000002      6736380.553           0.000
# L29.x1cos        -0.498823         0.000004      -136986.856           0.000
# L29.x1sin        -0.556064         0.000003      -188594.494           0.000
# L29.x2cos        -0.601826              NAN              NAN             NAN
# L29.x2sin         3.015551              NAN              NAN             NAN
# L29.x3cos         0.398489         0.000001       275893.610           0.000
# L29.x3sin        -0.077284              NAN              NAN             NAN
# L29.x4cos         0.585131              NAN              NAN             NAN
# L29.x4sin        -4.319672         0.000001     -3803866.168           0.000
# L30.x0cos         1.052322         0.000002       587853.826           0.000
# L30.x1cos         0.221589              NAN              NAN             NAN
# L30.x1sin         0.080730         0.000003        25873.723           0.000
# L30.x2cos        -0.168209         0.000003       -53410.714           0.000
# L30.x2sin        -0.280933         0.000001      -207284.447           0.000
# L30.x3cos        -0.258875              NAN              NAN             NAN
# L30.x3sin         0.373517              NAN              NAN             NAN
# L30.x4cos         0.463935         0.000003       171762.303           0.000
# L30.x4sin        -0.305272         0.000002      -151017.254           0.000
# L31.x0cos       -10.099628              NAN              NAN             NAN
# L31.x1cos         1.616846              NAN              NAN             NAN
# L31.x1sin        -1.281555              NAN              NAN             NAN
# L31.x2cos        -3.017958         0.000004      -822081.290           0.000
# L31.x2sin         0.489212         0.000004       125533.731           0.000
# L31.x3cos         0.323528              NAN              NAN             NAN
# L31.x3sin         0.147453              NAN              NAN             NAN
# L31.x4cos         0.665637              NAN              NAN             NAN
# L31.x4sin         0.697764              NAN              NAN             NAN
# L32.x0cos         7.721493         0.000002      4012371.001           0.000
# L32.x1cos         0.545124              NAN              NAN             NAN
# L32.x1sin         0.230537         0.000002       125763.597           0.000
# L32.x2cos        -1.033481         0.000002      -433992.866           0.000
# L32.x2sin         0.296584         0.000001       298787.994           0.000
# L32.x3cos         0.265319              NAN              NAN             NAN
# L32.x3sin        -0.199995              NAN              NAN             NAN
# L32.x4cos        -2.546156              NAN              NAN             NAN
# L32.x4sin        -0.772125         0.000002      -439400.664           0.000
# L33.x0cos        -0.471073         0.000001      -315937.804           0.000
# L33.x1cos        -0.800226         0.000002      -354970.691           0.000
# L33.x1sin         2.099473         0.000002       917753.833           0.000
# L33.x2cos         0.040092         0.000002        19808.563           0.000
# L33.x2sin        -2.797356         0.000001     -1928463.953           0.000
# L33.x3cos        -0.135464         0.000001      -108215.187           0.000
# L33.x3sin         0.471071         0.000001       809144.359           0.000
# L33.x4cos         1.413463         0.000002       661291.864           0.000
# L33.x4sin         0.624484         0.000002       280125.252           0.000
# L34.x0cos        -3.128446         0.000001     -2590677.537           0.000
# L34.x1cos         0.036233              NAN              NAN             NAN
# L34.x1sin        -0.101858              NAN              NAN             NAN
# L34.x2cos        -1.320858         0.000002      -765760.267           0.000
# L34.x2sin        -0.837173              NAN              NAN             NAN
# L34.x3cos        -0.207269         0.000002      -105429.519           0.000
# L34.x3sin         0.655958         0.000002       368871.152           0.000
# L34.x4cos         0.091495         0.000001        71394.115           0.000
# L34.x4sin         1.421537         0.000004       325772.373           0.000
# L35.x0cos         2.407447         0.000001      3170602.861           0.000
# L35.x1cos        -1.134837         0.000006      -176094.552           0.000
# L35.x1sin        -1.540210              NAN              NAN             NAN
# L35.x2cos         4.007109              NAN              NAN             NAN
# L35.x2sin        -0.762862         0.000003      -243790.251           0.000
# L35.x3cos        -0.636642              NAN              NAN             NAN
# L35.x3sin        -0.978569              NAN              NAN             NAN
# L35.x4cos         0.131540              NAN              NAN             NAN
# L35.x4sin        -2.317352         0.000001     -2753019.927           0.000
# L36.x0cos        -0.823355         0.000001      -852334.309           0.000
# L36.x1cos         1.147297         0.000005       220087.331           0.000
# L36.x1sin         0.633951              NAN              NAN             NAN
# L36.x2cos        -1.253350         0.000002      -561264.932           0.000
# L36.x2sin         1.949959              NAN              NAN             NAN
# L36.x3cos         0.603271              NAN              NAN             NAN
# L36.x3sin         0.159147              NAN              NAN             NAN
# L36.x4cos        -0.378418         0.000004       -99398.834           0.000
# L36.x4sin         1.184078         0.000002       650276.984           0.000
# L37.x0cos         0.116320              NAN              NAN             NAN
# L37.x1cos        -0.278680         0.000002      -143761.318           0.000
# L37.x1sin        -0.021259              NAN              NAN             NAN
# L37.x2cos        -0.106882              NAN              NAN             NAN
# L37.x2sin        -0.438309         0.000003      -158421.976           0.000
# L37.x3cos        -0.107161              NAN              NAN             NAN
# L37.x3sin         0.052597         0.000001        47815.634           0.000
# L37.x4cos         0.127807              NAN              NAN             NAN
# L37.x4sin        -0.207621              NAN              NAN             NAN
# ============================================================================
#
# Results for equation x1cos
# ============================================================================
#                coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------
# L1.x0cos          0.022769         0.000000        58573.832           0.000
# L1.x1cos          6.084897         0.000001     11878394.531           0.000
# L1.x1sin         -2.722063         0.000002     -1750540.840           0.000
# L1.x2cos         -0.000198              NAN              NAN             NAN
# L1.x2sin          0.054986              NAN              NAN             NAN
# L1.x3cos         -0.017956              NAN              NAN             NAN
# L1.x3sin         -0.027097         0.000000      -341333.322           0.000
# L1.x4cos          0.030818              NAN              NAN             NAN
# L1.x4sin         -0.014400              NAN              NAN             NAN
# L2.x0cos         -0.168294         0.000002      -111979.953           0.000
# L2.x1cos        -12.030646         0.000000    -30201581.174           0.000
# L2.x1sin         13.449462              NAN              NAN             NAN
# L2.x2cos         -0.225488         0.000001      -394527.254           0.000
# L2.x2sin         -0.189777         0.000000     -1558094.103           0.000
# L2.x3cos          0.164095              NAN              NAN             NAN
# L2.x3sin          0.041131              NAN              NAN             NAN
# L2.x4cos         -0.135319         0.000001      -166774.528           0.000
# L2.x4sin         -0.011148              NAN              NAN             NAN
# L3.x0cos          0.501689         0.000001       833053.897           0.000
# L3.x1cos          7.170533              NAN              NAN             NAN
# L3.x1sin        -22.184205              NAN              NAN             NAN
# L3.x2cos          0.569398              NAN              NAN             NAN
# L3.x2sin         -0.139776              NAN              NAN             NAN
# L3.x3cos         -0.288449              NAN              NAN             NAN
# L3.x3sin          0.170470         0.000001       203881.978           0.000
# L3.x4cos          0.056755              NAN              NAN             NAN
# L3.x4sin          0.367994         0.000002       217690.978           0.000
# L4.x0cos         -0.582504         0.000001      -411650.959           0.000
# L4.x1cos          0.791174              NAN              NAN             NAN
# L4.x1sin         10.023693         0.000001      8347019.152           0.000
# L4.x2cos         -0.059023              NAN              NAN             NAN
# L4.x2sin          0.479599         0.000001       370027.620           0.000
# L4.x3cos          0.028452              NAN              NAN             NAN
# L4.x3sin         -0.273910              NAN              NAN             NAN
# L4.x4cos          0.688008              NAN              NAN             NAN
# L4.x4sin         -1.287922              NAN              NAN             NAN
# L5.x0cos         -0.688537         0.000000     -1817848.187           0.000
# L5.x1cos          3.930867         0.000002      2121059.572           0.000
# L5.x1sin          5.826156              NAN              NAN             NAN
# L5.x2cos         -0.326000              NAN              NAN             NAN
# L5.x2sin          0.115051         0.000001       109737.171           0.000
# L5.x3cos          0.082258         0.000001       107695.387           0.000
# L5.x3sin         -0.048187         0.000000      -304903.064           0.000
# L5.x4cos         -1.617540              NAN              NAN             NAN
# L5.x4sin          2.431976         0.000001      4487162.302           0.000
# L6.x0cos          3.852519         0.000001      7057493.826           0.000
# L6.x1cos         -3.592441         0.000001     -2684258.368           0.000
# L6.x1sin         -2.599216         0.000002     -1431202.596           0.000
# L6.x2cos          0.148430              NAN              NAN             NAN
# L6.x2sin         -0.289712              NAN              NAN             NAN
# L6.x3cos          0.169061              NAN              NAN             NAN
# L6.x3sin          0.044118         0.000001        81148.134           0.000
# L6.x4cos          1.291077         0.000000      3382086.199           0.000
# L6.x4sin         -3.076594         0.000001     -4175580.764           0.000
# L7.x0cos         -7.362228         0.000001    -11911492.928           0.000
# L7.x1cos         -5.726737              NAN              NAN             NAN
# L7.x1sin         -0.695984              NAN              NAN             NAN
# L7.x2cos         -0.150036         0.000001      -142759.142           0.000
# L7.x2sin          0.465643              NAN              NAN             NAN
# L7.x3cos         -0.159299         0.000001      -214859.818           0.000
# L7.x3sin          0.281393         0.000000       632158.157           0.000
# L7.x4cos          0.448459         0.000001       518886.176           0.000
# L7.x4sin          2.421825              NAN              NAN             NAN
# L8.x0cos          8.521785         0.000001     10756073.535           0.000
# L8.x1cos          1.013820              NAN              NAN             NAN
# L8.x1sin         -0.217149              NAN              NAN             NAN
# L8.x2cos         -0.431759         0.000000     -1691586.928           0.000
# L8.x2sin         -0.359609         0.000002      -221202.519           0.000
# L8.x3cos          0.073406         0.000001       137396.577           0.000
# L8.x3sin         -0.382438              NAN              NAN             NAN
# L8.x4cos         -2.134568              NAN              NAN             NAN
# L8.x4sin         -0.230215         0.000001      -311102.375           0.000
# L9.x0cos         -6.459619         0.000000    -18018076.179           0.000
# L9.x1cos          4.192883         0.000003      1534717.747           0.000
# L9.x1sin         -3.502322         0.000004      -876048.121           0.000
# L9.x2cos          0.435669              NAN              NAN             NAN
# L9.x2sin          0.079823              NAN              NAN             NAN
# L9.x3cos         -0.151826              NAN              NAN             NAN
# L9.x3sin          0.306656              NAN              NAN             NAN
# L9.x4cos          2.477075         0.000001      2155743.490           0.000
# L9.x4sin         -1.960938         0.000001     -1578444.270           0.000
# L10.x0cos         2.852895         0.000001      2376284.835           0.000
# L10.x1cos        -0.185907              NAN              NAN             NAN
# L10.x1sin        -0.356242              NAN              NAN             NAN
# L10.x2cos        -0.793266              NAN              NAN             NAN
# L10.x2sin        -0.206486         0.000000      -420565.774           0.000
# L10.x3cos         0.232173         0.000000       469079.890           0.000
# L10.x3sin        -0.239194         0.000001      -302793.251           0.000
# L10.x4cos        -0.808083         0.000002      -334970.621           0.000
# L10.x4sin         2.166732         0.000003       769203.738           0.000
# L11.x0cos         0.569757         0.000000      1236739.403           0.000
# L11.x1cos         0.006274         0.000001         4962.731           0.000
# L11.x1sin         2.452190         0.000002      1180798.356           0.000
# L11.x2cos         0.596666              NAN              NAN             NAN
# L11.x2sin        -0.327636         0.000000      -907746.887           0.000
# L11.x3cos        -0.017741              NAN              NAN             NAN
# L11.x3sin         0.169649              NAN              NAN             NAN
# L11.x4cos        -2.034804         0.000000    -20952686.121           0.000
# L11.x4sin        -0.455870         0.000000     -5426129.365           0.000
# L12.x0cos        -3.372339         0.000000    -27953058.850           0.000
# L12.x1cos         1.463579              NAN              NAN             NAN
# L12.x1sin         1.815939         0.000001      1547534.312           0.000
# L12.x2cos        -0.220248              NAN              NAN             NAN
# L12.x2sin         0.159285              NAN              NAN             NAN
# L12.x3cos        -0.180040              NAN              NAN             NAN
# L12.x3sin         0.123053         0.000000       284433.361           0.000
# L12.x4cos         3.201486         0.000000     10657543.831           0.000
# L12.x4sin        -1.834998              NAN              NAN             NAN
# L13.x0cos         5.026580         0.000001      4184128.845           0.000
# L13.x1cos        -0.604929         0.000001      -813534.636           0.000
# L13.x1sin         0.307444         0.000002       167947.635           0.000
# L13.x2cos         0.120367         0.000001       160119.673           0.000
# L13.x2sin        -0.595482              NAN              NAN             NAN
# L13.x3cos        -0.068153         0.000001      -115604.684           0.000
# L13.x3sin        -0.217516         0.000000      -559338.238           0.000
# L13.x4cos        -1.140400              NAN              NAN             NAN
# L13.x4sin         2.918631              NAN              NAN             NAN
# L14.x0cos        -4.657782              NAN              NAN             NAN
# L14.x1cos        -2.464875         0.000001     -4357474.643           0.000
# L14.x1sin        -0.885296         0.000003      -283460.532           0.000
# L14.x2cos         0.243385              NAN              NAN             NAN
# L14.x2sin         0.383740              NAN              NAN             NAN
# L14.x3cos         0.288676              NAN              NAN             NAN
# L14.x3sin        -0.075996         0.000001      -109366.720           0.000
# L14.x4cos        -2.135398              NAN              NAN             NAN
# L14.x4sin        -1.164981         0.000001     -1328599.946           0.000
# L15.x0cos         2.899917         0.000000      9643693.847           0.000
# L15.x1cos        -0.858312              NAN              NAN             NAN
# L15.x1sin        -0.164675         0.000001      -179933.143           0.000
# L15.x2cos         0.014470              NAN              NAN             NAN
# L15.x2sin        -0.536758              NAN              NAN             NAN
# L15.x3cos        -0.239566              NAN              NAN             NAN
# L15.x3sin         0.265317              NAN              NAN             NAN
# L15.x4cos         3.323111              NAN              NAN             NAN
# L15.x4sin        -1.605850              NAN              NAN             NAN
# L16.x0cos        -1.686944         0.000001     -2053489.885           0.000
# L16.x1cos         1.392789         0.000002       802635.591           0.000
# L16.x1sin        -0.042678              NAN              NAN             NAN
# L16.x2cos         0.412629              NAN              NAN             NAN
# L16.x2sin         0.098145              NAN              NAN             NAN
# L16.x3cos         0.078405              NAN              NAN             NAN
# L16.x3sin        -0.406171         0.000000     -1030592.105           0.000
# L16.x4cos        -1.521596              NAN              NAN             NAN
# L16.x4sin         1.476989              NAN              NAN             NAN
# L17.x0cos         1.306054              NAN              NAN             NAN
# L17.x1cos        -0.180498         0.000002      -111554.825           0.000
# L17.x1sin        -1.483126         0.000002      -947540.796           0.000
# L17.x2cos         0.566557              NAN              NAN             NAN
# L17.x2sin        -0.059989              NAN              NAN             NAN
# L17.x3cos         0.384275         0.000000      2198757.743           0.000
# L17.x3sin         0.326824              NAN              NAN             NAN
# L17.x4cos        -0.600835              NAN              NAN             NAN
# L17.x4sin         1.809242         0.000000      6107306.800           0.000
# L18.x0cos         0.152967         0.000000       731256.939           0.000
# L18.x1cos         0.534657              NAN              NAN             NAN
# L18.x1sin        -0.234013              NAN              NAN             NAN
# L18.x2cos         0.226764              NAN              NAN             NAN
# L18.x2sin         0.789208              NAN              NAN             NAN
# L18.x3cos        -0.221884         0.000001      -320429.141           0.000
# L18.x3sin         0.217012              NAN              NAN             NAN
# L18.x4cos         1.215688              NAN              NAN             NAN
# L18.x4sin        -4.706591         0.000000    -11111731.005           0.000
# L19.x0cos        -3.200487         0.000000     -6607158.874           0.000
# L19.x1cos         0.178246              NAN              NAN             NAN
# L19.x1sin         0.722913         0.000002       433193.121           0.000
# L19.x2cos        -0.171015         0.000001      -137231.523           0.000
# L19.x2sin         0.418837         0.000003       164189.141           0.000
# L19.x3cos        -0.355973              NAN              NAN             NAN
# L19.x3sin         0.064331         0.000000       148134.357           0.000
# L19.x4cos        -1.636902              NAN              NAN             NAN
# L19.x4sin         3.660184              NAN              NAN             NAN
# L20.x0cos         4.986940              NAN              NAN             NAN
# L20.x1cos         0.712089         0.000000      4049274.228           0.000
# L20.x1sin         0.557390              NAN              NAN             NAN
# L20.x2cos        -0.214342              NAN              NAN             NAN
# L20.x2sin         0.144013         0.000001       148121.399           0.000
# L20.x3cos        -0.100748         0.000000      -392996.074           0.000
# L20.x3sin        -0.270032         0.000001      -339246.323           0.000
# L20.x4cos         1.649190         0.000000      3709955.654           0.000
# L20.x4sin         0.782683              NAN              NAN             NAN
# L21.x0cos        -3.127885              NAN              NAN             NAN
# L21.x1cos        -0.426166         0.000001      -472993.465           0.000
# L21.x1sin        -0.045833              NAN              NAN             NAN
# L21.x2cos        -0.463290         0.000000      -946396.780           0.000
# L21.x2sin         0.175421         0.000002        86115.172           0.000
# L21.x3cos         0.343465         0.000000      2395934.941           0.000
# L21.x3sin        -0.308676         0.000001      -533754.214           0.000
# L21.x4cos        -0.377986         0.000000      -986714.288           0.000
# L21.x4sin        -3.359709         0.000002     -1616066.015           0.000
# L22.x0cos        -0.196870         0.000001      -141831.465           0.000
# L22.x1cos         0.315465              NAN              NAN             NAN
# L22.x1sin         0.089022         0.000001        67916.006           0.000
# L22.x2cos         0.063988         0.000000       149148.171           0.000
# L22.x2sin         0.176320         0.000000      1451795.520           0.000
# L22.x3cos        -0.139541         0.000001      -151110.090           0.000
# L22.x3sin         0.525834         0.000001       374416.775           0.000
# L22.x4cos        -0.115344              NAN              NAN             NAN
# L22.x4sin         2.057823         0.000000      4498601.316           0.000
# L23.x0cos         1.051992              NAN              NAN             NAN
# L23.x1cos        -0.728432              NAN              NAN             NAN
# L23.x1sin         0.401344              NAN              NAN             NAN
# L23.x2cos        -0.462998         0.000001      -495701.781           0.000
# L23.x2sin        -0.454817         0.000001      -524764.509           0.000
# L23.x3cos        -0.235406         0.000001      -393044.569           0.000
# L23.x3sin        -0.241527         0.000001      -282599.894           0.000
# L23.x4cos        -0.291378         0.000001      -492845.125           0.000
# L23.x4sin        -0.757941         0.000001      -817702.604           0.000
# L24.x0cos         0.563737              NAN              NAN             NAN
# L24.x1cos        -0.165990         0.000001      -195774.515           0.000
# L24.x1sin         0.501001              NAN              NAN             NAN
# L24.x2cos        -0.030769         0.000002       -15787.699           0.000
# L24.x2sin         0.233235              NAN              NAN             NAN
# L24.x3cos         0.071726         0.000001        67094.955           0.000
# L24.x3sin        -0.476841         0.000001      -578516.300           0.000
# L24.x4cos        -0.152617         0.000002      -101720.037           0.000
# L24.x4sin         0.759662              NAN              NAN             NAN
# L25.x0cos        -1.648436         0.000001     -1138138.853           0.000
# L25.x1cos        -0.642495              NAN              NAN             NAN
# L25.x1sin        -0.758815              NAN              NAN             NAN
# L25.x2cos         0.082205         0.000001        61281.084           0.000
# L25.x2sin        -0.039766              NAN              NAN             NAN
# L25.x3cos         0.345292         0.000000      1478784.166           0.000
# L25.x3sin         0.286118              NAN              NAN             NAN
# L25.x4cos        -0.534664              NAN              NAN             NAN
# L25.x4sin        -0.428951              NAN              NAN             NAN
# L26.x0cos         1.711568         0.000001      3245317.861           0.000
# L26.x1cos         0.382216         0.000002       205080.199           0.000
# L26.x1sin        -0.759687         0.000001      -950787.927           0.000
# L26.x2cos        -0.388333              NAN              NAN             NAN
# L26.x2sin        -0.200629         0.000000      -534477.214           0.000
# L26.x3cos        -0.063523         0.000001       -79283.434           0.000
# L26.x3sin        -0.259832              NAN              NAN             NAN
# L26.x4cos         3.026442         0.000001      2025484.693           0.000
# L26.x4sin         0.633688         0.000000      1801570.844           0.000
# L27.x0cos        -2.678818              NAN              NAN             NAN
# L27.x1cos         0.054023              NAN              NAN             NAN
# L27.x1sin        -0.136715              NAN              NAN             NAN
# L27.x2cos        -0.230963         0.000001      -179556.114           0.000
# L27.x2sin        -0.103027         0.000000      -490190.222           0.000
# L27.x3cos         0.447584         0.000001       710522.136           0.000
# L27.x3sin         0.324555         0.000001       541684.416           0.000
# L27.x4cos        -3.353102         0.000002     -2226208.618           0.000
# L27.x4sin        -1.617934              NAN              NAN             NAN
# L28.x0cos         4.038829              NAN              NAN             NAN
# L28.x1cos         0.528539              NAN              NAN             NAN
# L28.x1sin         0.203208         0.000003        59911.386           0.000
# L28.x2cos         0.157376              NAN              NAN             NAN
# L28.x2sin        -0.289849         0.000001      -410134.816           0.000
# L28.x3cos        -0.235350              NAN              NAN             NAN
# L28.x3sin         0.323762         0.000000       909308.408           0.000
# L28.x4cos         0.732744         0.000001       787437.426           0.000
# L28.x4sin         1.443007         0.000001      1200053.862           0.000
# L29.x0cos        -3.162219         0.000001     -4931750.553           0.000
# L29.x1cos         0.721524         0.000001       500406.138           0.000
# L29.x1sin        -0.032463         0.000001       -27805.535           0.000
# L29.x2cos         0.219132              NAN              NAN             NAN
# L29.x2sin        -0.505376              NAN              NAN             NAN
# L29.x3cos        -0.355120         0.000001      -620926.258           0.000
# L29.x3sin        -0.117134              NAN              NAN             NAN
# L29.x4cos         1.172856              NAN              NAN             NAN
# L29.x4sin        -0.151784         0.000000      -337551.410           0.000
# L30.x0cos         0.290921         0.000001       410425.812           0.000
# L30.x1cos        -0.300165              NAN              NAN             NAN
# L30.x1sin         1.302665         0.000001      1054372.595           0.000
# L30.x2cos         0.027785         0.000001        22280.783           0.000
# ...
# L16.x3cos        -0.011245              NAN              NAN             NAN
# L16.x3sin        -0.162626         0.000000      -939184.633           0.000
# L16.x4cos        -0.060417              NAN              NAN             NAN
# L16.x4sin         0.307335              NAN              NAN             NAN
# L17.x0cos         0.534502              NAN              NAN             NAN
# L17.x1cos        -0.039303         0.000001       -55287.628           0.000
# L17.x1sin         0.327685         0.000001       476496.610           0.000
# L17.x2cos        -0.005363              NAN              NAN             NAN
# L17.x2sin        -0.036567              NAN              NAN             NAN
# L17.x3cos        -0.059405         0.000000      -773638.003           0.000
# L17.x3sin        -0.027505              NAN              NAN             NAN
# L17.x4cos         0.924253              NAN              NAN             NAN
# L17.x4sin         2.936358         0.000000     22560298.131           0.000
# L18.x0cos        -1.932205         0.000000    -21023695.919           0.000
# L18.x1cos        -0.201637              NAN              NAN             NAN
# L18.x1sin        -0.088706              NAN              NAN             NAN
# L18.x2cos         0.013879              NAN              NAN             NAN
# L18.x2sin        -0.226268              NAN              NAN             NAN
# L18.x3cos         0.065307         0.000000       214659.241           0.000
# L18.x3sin        -0.003570              NAN              NAN             NAN
# L18.x4cos        -0.839179              NAN              NAN             NAN
# L18.x4sin         0.479870         0.000000      2578586.314           0.000
# L19.x0cos         1.386055         0.000000      6512713.737           0.000
# L19.x1cos         0.103018              NAN              NAN             NAN
# L19.x1sin        -0.080615         0.000001      -109949.651           0.000
# L19.x2cos        -0.091267         0.000001      -166692.889           0.000
# L19.x2sin         0.045068         0.000001        40211.417           0.000
# L19.x3cos         0.089494              NAN              NAN             NAN
# L19.x3sin        -0.151843         0.000000      -795814.447           0.000
# L19.x4cos         1.036486              NAN              NAN             NAN
# L19.x4sin        -2.183928              NAN              NAN             NAN
# L20.x0cos         0.724493              NAN              NAN             NAN
# L20.x1cos        -0.008548         0.000000      -110629.685           0.000
# L20.x1sin         0.019348              NAN              NAN             NAN
# L20.x2cos         0.153722              NAN              NAN             NAN
# L20.x2sin        -0.199576         0.000000      -467206.055           0.000
# L20.x3cos         0.136102         0.000000      1208370.290           0.000
# L20.x3sin         0.085377         0.000000       244129.745           0.000
# L20.x4cos         0.205278         0.000000      1051047.931           0.000
# L20.x4sin        -1.690769              NAN              NAN             NAN
# L21.x0cos        -2.197111              NAN              NAN             NAN
# L21.x1cos        -0.174942         0.000000      -441929.470           0.000
# L21.x1sin         0.051951              NAN              NAN             NAN
# L21.x2cos        -0.037038         0.000000      -172206.919           0.000
# L21.x2sin         0.004200         0.000001         4692.777           0.000
# L21.x3cos         0.029030         0.000000       460924.067           0.000
# L21.x3sin         0.195247         0.000000       768432.137           0.000
# L21.x4cos        -0.813197         0.000000     -4831634.515           0.000
# L21.x4sin         1.398172         0.000001      1530738.072           0.000
# L22.x0cos         1.339081         0.000001      2195744.687           0.000
# L22.x1cos         0.105197              NAN              NAN             NAN
# L22.x1sin        -0.141189         0.000001      -245164.750           0.000
# L22.x2cos         0.115247         0.000000       611411.569           0.000
# L22.x2sin        -0.180920         0.000000     -3390579.338           0.000
# L22.x3cos        -0.250881         0.000000      -618359.946           0.000
# L22.x3sin         0.015385         0.000001        24933.196           0.000
# L22.x4cos        -1.744537              NAN              NAN             NAN
# L22.x4sin         2.345093         0.000000     11668430.768           0.000
# L23.x0cos         0.992904              NAN              NAN             NAN
# L23.x1cos         0.158175              NAN              NAN             NAN
# L23.x1sin        -0.063992              NAN              NAN             NAN
# L23.x2cos         0.076265         0.000000       185844.432           0.000
# L23.x2sin         0.111863         0.000000       293763.066           0.000
# L23.x3cos         0.225949         0.000000       858653.764           0.000
# L23.x3sin        -0.144846         0.000000      -385741.476           0.000
# L23.x4cos         1.515596         0.000000      5834726.322           0.000
# L23.x4sin        -0.290870         0.000000      -714234.932           0.000
# L24.x0cos        -2.099584              NAN              NAN             NAN
# L24.x1cos        -0.234640         0.000000      -629881.767           0.000
# L24.x1sin         0.118580              NAN              NAN             NAN
# L24.x2cos         0.147816         0.000001       172628.708           0.000
# L24.x2sin        -0.144831              NAN              NAN             NAN
# L24.x3cos        -0.225724         0.000000      -480591.258           0.000
# L24.x3sin         0.079420         0.000000       219308.924           0.000
# L24.x4cos         1.388231         0.000001      2105954.462           0.000
# L24.x4sin        -2.636959              NAN              NAN             NAN
# L25.x0cos         0.699943         0.000001      1099939.357           0.000
# L25.x1cos         0.180014              NAN              NAN             NAN
# L25.x1sin        -0.045030              NAN              NAN             NAN
# L25.x2cos         0.118379         0.000001       200856.841           0.000
# L25.x2sin         0.107494              NAN              NAN             NAN
# L25.x3cos         0.238597         0.000000      2325764.801           0.000
# L25.x3sin         0.079666              NAN              NAN             NAN
# L25.x4cos         1.199542              NAN              NAN             NAN
# L25.x4sin         0.851427              NAN              NAN             NAN
# L26.x0cos         1.274617         0.000000      5500796.481           0.000
# L26.x1cos         0.219399         0.000001       267936.526           0.000
# L26.x1sin        -0.088052         0.000000      -250826.107           0.000
# L26.x2cos        -0.032571              NAN              NAN             NAN
# L26.x2sin         0.074970         0.000000       454576.582           0.000
# L26.x3cos        -0.226834         0.000000      -644384.079           0.000
# L26.x3sin        -0.058956              NAN              NAN             NAN
# L26.x4cos        -3.622079         0.000001     -5517437.745           0.000
# L26.x4sin         0.226135         0.000000      1463275.883           0.000
# L27.x0cos        -1.350332              NAN              NAN             NAN
# L27.x1cos        -0.294357              NAN              NAN             NAN
# L27.x1sin         0.274970              NAN              NAN             NAN
# L27.x2cos         0.255941         0.000001       452878.138           0.000
# L27.x2sin         0.186083         0.000000      2015134.596           0.000
# L27.x3cos        -0.023368         0.000000       -84433.372           0.000
# L27.x3sin        -0.048201         0.000000      -183103.769           0.000
# L27.x4cos        -0.597712         0.000001      -903220.379           0.000
# L27.x4sin        -0.356088              NAN              NAN             NAN
# L28.x0cos        -0.027963              NAN              NAN             NAN
# L28.x1cos         0.138395              NAN              NAN             NAN
# L28.x1sin         0.072444         0.000001        48613.057           0.000
# L28.x2cos        -0.264730              NAN              NAN             NAN
# L28.x2sin        -0.142654         0.000000      -459434.118           0.000
# L28.x3cos         0.228508              NAN              NAN             NAN
# L28.x3sin        -0.003759         0.000000       -24026.428           0.000
# L28.x4cos         1.428292         0.000000      3493524.265           0.000
# L28.x4sin         0.731375         0.000001      1384380.378           0.000
# L29.x0cos         0.629310         0.000000      2233865.226           0.000
# L29.x1cos        -0.290982         0.000001      -459326.109           0.000
# L29.x1sin        -0.155450         0.000001      -303052.016           0.000
# L29.x2cos         0.161552              NAN              NAN             NAN
# L29.x2sin         0.393296              NAN              NAN             NAN
# L29.x3cos        -0.199260         0.000000      -792990.818           0.000
# L29.x3sin         0.107905              NAN              NAN             NAN
# L29.x4cos         2.615716              NAN              NAN             NAN
# L29.x4sin         1.819482         0.000000      9209678.677           0.000
# L30.x0cos        -0.071463         0.000000      -229468.060           0.000
# L30.x1cos         0.063453              NAN              NAN             NAN
# L30.x1sin        -0.102507         0.000001      -188840.812           0.000
# L30.x2cos        -0.106098         0.000001      -193644.585           0.000
# L30.x2sin        -0.104955         0.000000      -445134.195           0.000
# L30.x3cos         0.012717              NAN              NAN             NAN
# L30.x3sin        -0.074453              NAN              NAN             NAN
# L30.x4cos        -1.537041         0.000000     -3270984.184           0.000
# L30.x4sin        -2.467201         0.000000     -7015620.257           0.000
# L31.x0cos        -0.063802              NAN              NAN             NAN
# L31.x1cos         0.004895              NAN              NAN             NAN
# L31.x1sin        -0.100007              NAN              NAN             NAN
# L31.x2cos        -0.215083         0.000001      -336766.835           0.000
# L31.x2sin         0.012372         0.000001        18248.278           0.000
# L31.x3cos        -0.039117              NAN              NAN             NAN
# L31.x3sin        -0.061836              NAN              NAN             NAN
# L31.x4cos        -1.289185              NAN              NAN             NAN
# L31.x4sin        -1.866782              NAN              NAN             NAN
# L32.x0cos        -0.831609         0.000000     -2483941.737           0.000
# L32.x1cos         0.350872              NAN              NAN             NAN
# L32.x1sin         0.016182         0.000000        50741.756           0.000
# L32.x2cos         0.027187         0.000000        65625.174           0.000
# L32.x2sin         0.128959         0.000000       746774.070           0.000
# L32.x3cos         0.131626              NAN              NAN             NAN
# L32.x3sin        -0.074198              NAN              NAN             NAN
# L32.x4cos        -0.620441              NAN              NAN             NAN
# L32.x4sin         2.303282         0.000000      7534291.778           0.000
# L33.x0cos         1.628435         0.000000      6277773.687           0.000
# L33.x1cos        -0.148992         0.000000      -379894.836           0.000
# L33.x1sin         0.256320         0.000000       644051.463           0.000
# L33.x2cos        -0.124361         0.000000      -353188.427           0.000
# L33.x2sin        -0.267292         0.000000     -1059183.626           0.000
# L33.x3cos         0.033172         0.000000       152320.625           0.000
# L33.x3sin         0.156952         0.000000      1549627.364           0.000
# L33.x4cos         1.928242         0.000000      5185521.108           0.000
# L33.x4sin         3.145947         0.000000      8111566.474           0.000
# L34.x0cos        -1.460265         0.000000     -6950860.463           0.000
# L34.x1cos        -0.182248              NAN              NAN             NAN
# L34.x1sin        -0.012015              NAN              NAN             NAN
# L34.x2cos        -0.055122         0.000000      -183688.870           0.000
# L34.x2sin        -0.015234              NAN              NAN             NAN
# L34.x3cos        -0.086975         0.000000      -254297.514           0.000
# L34.x3sin        -0.020186         0.000000       -65249.518           0.000
# L34.x4cos         0.281686         0.000000      1263428.875           0.000
# L34.x4sin        -5.735769         0.000001     -7555614.433           0.000
# L35.x0cos         0.747985         0.000000      5662391.917           0.000
# L35.x1cos         0.077173         0.000001        68833.258           0.000
# L35.x1sin        -0.194852              NAN              NAN             NAN
# L35.x2cos         0.271999              NAN              NAN             NAN
# L35.x2sin        -0.119577         0.000001      -219654.700           0.000
# L35.x3cos         0.009721              NAN              NAN             NAN
# L35.x3sin        -0.018191              NAN              NAN             NAN
# L35.x4cos        -1.644817              NAN              NAN             NAN
# L35.x4sin         3.348650         0.000000     22867002.161           0.000
# L36.x0cos        -0.215175         0.000000     -1280373.986           0.000
# L36.x1cos         0.035224         0.000001        38840.250           0.000
# L36.x1sin         0.093713              NAN              NAN             NAN
# L36.x2cos        -0.065034         0.000000      -167400.959           0.000
# L36.x2sin         0.168952              NAN              NAN             NAN
# L36.x3cos         0.004326              NAN              NAN             NAN
# L36.x3sin        -0.003361              NAN              NAN             NAN
# L36.x4cos         0.914322         0.000001      1380484.117           0.000
# L36.x4sin        -0.828316         0.000000     -2614784.945           0.000
# L37.x0cos         0.027435              NAN              NAN             NAN
# L37.x1cos        -0.014854         0.000000       -44044.409           0.000
# L37.x1sin        -0.009744              NAN              NAN             NAN
# L37.x2cos        -0.015121              NAN              NAN             NAN
# L37.x2sin        -0.033028         0.000000       -68618.367           0.000
# L37.x3cos         0.000742              NAN              NAN             NAN
# L37.x3sin         0.001779         0.000000         9296.420           0.000
# L37.x4cos        -0.161867              NAN              NAN             NAN
# L37.x4sin         0.063046              NAN              NAN             NAN
# ============================================================================
#
# Correlation matrix of residuals
#             x0cos     x1cos     x1sin     x2cos     x2sin     x3cos     x3sin     x4cos     x4sin
# x0cos    1.000000 -0.279978  0.018250 -0.139802  0.094624  0.182573  0.157494  0.673845  0.331680
# x1cos   -0.279978  1.000000 -0.011817  0.022582 -0.031357 -0.040573 -0.049240 -0.228787 -0.115550
# x1sin    0.018250 -0.011817  1.000000  0.008513 -0.007927  0.023618  0.008073  0.045224  0.030059
# x2cos   -0.139802  0.022582  0.008513  1.000000  0.000286 -0.010554 -0.030734 -0.091274 -0.040464
# x2sin    0.094624 -0.031357 -0.007927  0.000286  1.000000  0.021786  0.026159  0.043117  0.008395
# x3cos    0.182573 -0.040573  0.023618 -0.010554  0.021786  1.000000  0.030019  0.180048  0.076769
# x3sin    0.157494 -0.049240  0.008073 -0.030734  0.026159  0.030019  1.000000  0.144732  0.060733
# x4cos    0.673845 -0.228787  0.045224 -0.091274  0.043117  0.180048  0.144732  1.000000  0.253937
# x4sin    0.331680 -0.115550  0.030059 -0.040464  0.008395  0.076769  0.060733  0.253937  1.000000

# %%
# Wald Test
causal_results = results.test_causality('x0cos', 'x1cos', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0cos', 'x1sin', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0cos', 'x2cos', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0cos', 'x2sin', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0cos', 'x3cos', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0cos', 'x3sin', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0cos', 'x4cos', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0cos', 'x4sin', kind='Wald')
print(causal_results.summary())
# Out:
# Granger causality Wald-test. H_0: x1cos does not Granger-cause x0cos. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   6.842e+13        52.19       0.000  37
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x1sin does not Granger-cause x0cos. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   1.837e+13        52.19       0.000  37
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x2cos does not Granger-cause x0cos. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   -6.301e+13       52.19       1.000  37
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x2sin does not Granger-cause x0cos. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   5.370e+13        52.19       0.000  37
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x3cos does not Granger-cause x0cos. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   -1.219e+12       52.19       1.000  37
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x3sin does not Granger-cause x0cos. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   3.085e+12        52.19       0.000  37
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x4cos does not Granger-cause x0cos. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   -2.417e+13       52.19       1.000  37
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x4sin does not Granger-cause x0cos. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   -1.474e+13       52.19       1.000  37
# ----------------------------------------

# %%
kuramoto_df_wo_x0sin=kuramoto_df.drop(columns=['x0cos'])
model = VAR(kuramoto_df_wo_x0sin)
#find optimal lag order by information criteria
lag_orders_data = model.select_order(trend='nc')
print(lag_orders_data.selected_orders)
results = model.fit(lag_orders_data.selected_orders['bic'],trend='nc')
print(results.summary())
# Out:
# {'aic': 36, 'bic': 36, 'hqic': 36, 'fpe': 36}
# /usr/local/lib/python3.6/site-packages/statsmodels/tsa/vector_ar/var_model.py:1387: RuntimeWarning: invalid value encountered in sqrt
#   stderr = np.sqrt(np.diag(self.cov_params))
# /usr/local/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /usr/local/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /usr/local/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 06, Jun, 2019
# Time:                     23:37:48
# --------------------------------------------------------------------
# No. of Equations:         9.00000    BIC:                   -484.379
# Nobs:                     9965.00    HQIC:                  -485.774
# Log likelihood:       2.29959e+06    FPE:               5.25970e-212
# AIC:                     -486.488    Det(Omega_mle):    3.94365e-212
# --------------------------------------------------------------------
# Results for equation x0sin
# ============================================================================
#                coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------
# L1.x0sin          8.917078         0.000001     12147202.196           0.000
# L1.x1cos         -0.013764              NAN              NAN             NAN
# L1.x1sin         -0.021720         0.000001       -41467.416           0.000
# L1.x2cos         -0.080628         0.000001       -60405.682           0.000
# L1.x2sin         -0.065577         0.000003       -19686.210           0.000
# L1.x3cos         -0.030844              NAN              NAN             NAN
# L1.x3sin          0.024450         0.000001        29494.177           0.000
# L1.x4cos         -0.166349         0.000000      -357962.386           0.000
# L1.x4sin         -0.147123              NAN              NAN             NAN
# L2.x0sin        -36.354555              NAN              NAN             NAN
# L2.x1cos          0.037031              NAN              NAN             NAN
# L2.x1sin          0.084617              NAN              NAN             NAN
# L2.x2cos          0.565949              NAN              NAN             NAN
# L2.x2sin         -0.078777         0.000005       -16920.670           0.000
# L2.x3cos          0.029017         0.000001        26288.355           0.000
# L2.x3sin         -0.191400              NAN              NAN             NAN
# L2.x4cos          0.744057         0.000000     25962701.633           0.000
# L2.x4sin          1.135270              NAN              NAN             NAN
# L3.x0sin         87.523324         0.000001    157814821.594           0.000
# L3.x1cos          0.085686              NAN              NAN             NAN
# L3.x1sin         -0.249837              NAN              NAN             NAN
# L3.x2cos         -0.630182              NAN              NAN             NAN
# L3.x2sin          0.932748              NAN              NAN             NAN
# L3.x3cos          0.190712              NAN              NAN             NAN
# L3.x3sin          0.226177         0.000001       215631.211           0.000
# L3.x4cos         -0.902893         0.000000     -3956250.372           0.000
# L3.x4sin         -3.235575         0.000000    -15734218.740           0.000
# L4.x0sin       -132.269492         0.000001    -97909755.046           0.000
# L4.x1cos         -0.306051              NAN              NAN             NAN
# L4.x1sin          0.548177              NAN              NAN             NAN
# L4.x2cos         -0.230281         0.000000      -548480.097           0.000
# L4.x2sin         -0.624194              NAN              NAN             NAN
# L4.x3cos         -0.002899         0.000001        -3296.550           0.000
# L4.x3sin          0.168380              NAN              NAN             NAN
# L4.x4cos         -0.471235         0.000001      -473998.423           0.000
# L4.x4sin          3.775977              NAN              NAN             NAN
# L5.x0sin        117.314068         0.000001     85216819.300           0.000
# L5.x1cos          0.419397              NAN              NAN             NAN
# L5.x1sin         -0.440230              NAN              NAN             NAN
# L5.x2cos         -0.443660              NAN              NAN             NAN
# L5.x2sin         -0.459845         0.000002      -241036.134           0.000
# L5.x3cos         -0.572233              NAN              NAN             NAN
# L5.x3sin         -0.082479              NAN              NAN             NAN
# L5.x4cos          1.091010              NAN              NAN             NAN
# L5.x4sin          0.069310              NAN              NAN             NAN
# L6.x0sin        -33.974235         0.000000    -72472040.446           0.000
# L6.x1cos         -0.751209         0.000001      -526408.529           0.000
# L6.x1sin          0.039854         0.000001        45522.800           0.000
# L6.x2cos          0.608408              NAN              NAN             NAN
# L6.x2sin         -0.080486              NAN              NAN             NAN
# L6.x3cos          0.370535              NAN              NAN             NAN
# L6.x3sin         -0.004319         0.000001        -7672.057           0.000
# L6.x4cos          1.491067         0.000001      2610215.893           0.000
# L6.x4sin         -4.528237              NAN              NAN             NAN
# L7.x0sin        -44.805387         0.000001    -42123769.526           0.000
# L7.x1cos          0.658644         0.000001      1171586.703           0.000
# L7.x1sin         -0.528262         0.000001     -1049157.014           0.000
# L7.x2cos          0.224562              NAN              NAN             NAN
# L7.x2sin         -0.416462         0.000001      -594001.080           0.000
# L7.x3cos         -0.296545         0.000000      -643390.398           0.000
# L7.x3sin         -0.422272              NAN              NAN             NAN
# L7.x4cos         -2.731835              NAN              NAN             NAN
# L7.x4sin          4.210247              NAN              NAN             NAN
# L8.x0sin         43.032586              NAN              NAN             NAN
# L8.x1cos          0.302660         0.000002       191884.609           0.000
# L8.x1sin          0.982417         0.000001       989278.893           0.000
# L8.x2cos          0.168396              NAN              NAN             NAN
# L8.x2sin          0.114081         0.000003        39896.334           0.000
# L8.x3cos          0.230158         0.000000       804624.155           0.000
# L8.x3sin          0.209056              NAN              NAN             NAN
# L8.x4cos         -1.064759              NAN              NAN             NAN
# L8.x4sin         -1.709346         0.000000     -4600596.322           0.000
# L9.x0sin         15.507855              NAN              NAN             NAN
# L9.x1cos         -0.164424              NAN              NAN             NAN
# L9.x1sin         -0.632773         0.000001     -1193927.745           0.000
# L9.x2cos          0.440557              NAN              NAN             NAN
# L9.x2sin          0.497602              NAN              NAN             NAN
# L9.x3cos          0.139373              NAN              NAN             NAN
# L9.x3sin         -0.113919              NAN              NAN             NAN
# L9.x4cos          3.479756         0.000000     19885418.918           0.000
# L9.x4sin          0.994678         0.000001      1442579.540           0.000
# L10.x0sin       -41.403701              NAN              NAN             NAN
# L10.x1cos        -0.552058              NAN              NAN             NAN
# L10.x1sin         0.674006         0.000001       669658.531           0.000
# L10.x2cos         0.014605         0.000002         7845.263           0.000
# L10.x2sin        -0.232888              NAN              NAN             NAN
# L10.x3cos        -0.033603              NAN              NAN             NAN
# L10.x3sin         0.086912              NAN              NAN             NAN
# L10.x4cos        -0.067137         0.000001       -97835.390           0.000
# L10.x4sin        -0.835815         0.000001     -1430466.622           0.000
# L11.x0sin         7.823548         0.000001      9961917.881           0.000
# L11.x1cos         0.167357              NAN              NAN             NAN
# L11.x1sin        -0.306139              NAN              NAN             NAN
# L11.x2cos         0.021435         0.000003         7346.359           0.000
# L11.x2sin         0.345756         0.000001       438609.649           0.000
# L11.x3cos        -0.209820              NAN              NAN             NAN
# L11.x3sin        -0.129493              NAN              NAN             NAN
# L11.x4cos        -3.409180         0.000001     -4046532.958           0.000
# L11.x4sin         1.307069         0.000000      3803071.941           0.000
# L12.x0sin        24.261921              NAN              NAN             NAN
# L12.x1cos         0.033660              NAN              NAN             NAN
# L12.x1sin        -0.246772              NAN              NAN             NAN
# L12.x2cos         0.088476         0.000001       146921.529           0.000
# L12.x2sin         0.370022         0.000002       197377.455           0.000
# L12.x3cos         0.518194         0.000001       438130.401           0.000
# L12.x3sin        -0.162585              NAN              NAN             NAN
# L12.x4cos         2.785932         0.000000      5928760.244           0.000
# L12.x4sin        -2.508806              NAN              NAN             NAN
# L13.x0sin       -10.902913              NAN              NAN             NAN
# L13.x1cos         0.003897              NAN              NAN             NAN
# L13.x1sin         0.043134              NAN              NAN             NAN
# L13.x2cos         0.241395              NAN              NAN             NAN
# L13.x2sin         0.280871              NAN              NAN             NAN
# L13.x3cos         0.089961              NAN              NAN             NAN
# L13.x3sin         0.402203              NAN              NAN             NAN
# L13.x4cos        -0.634008              NAN              NAN             NAN
# L13.x4sin         1.187993         0.000001      1189489.963           0.000
# L14.x0sin       -16.043827              NAN              NAN             NAN
# L14.x1cos        -0.225812         0.000001      -327891.422           0.000
# L14.x1sin        -0.137797              NAN              NAN             NAN
# L14.x2cos        -0.756067              NAN              NAN             NAN
# L14.x2sin         0.040972              NAN              NAN             NAN
# L14.x3cos        -0.128611         0.000001      -132720.601           0.000
# L14.x3sin        -0.028661         0.000000       -60210.081           0.000
# L14.x4cos        -0.360456              NAN              NAN             NAN
# L14.x4sin         1.512166              NAN              NAN             NAN
# L15.x0sin        13.947379         0.000001     13424451.970           0.000
# L15.x1cos         0.308371         0.000001       231424.139           0.000
# L15.x1sin         0.029484         0.000000        87753.182           0.000
# L15.x2cos        -0.004783              NAN              NAN             NAN
# L15.x2sin         0.483081              NAN              NAN             NAN
# L15.x3cos         0.092749              NAN              NAN             NAN
# L15.x3sin         0.283492              NAN              NAN             NAN
# L15.x4cos         0.122541              NAN              NAN             NAN
# L15.x4sin        -1.150146              NAN              NAN             NAN
# L16.x0sin         4.969646              NAN              NAN             NAN
# L16.x1cos         0.475716         0.000001       908128.171           0.000
# L16.x1sin        -0.141514         0.000001      -179234.143           0.000
# L16.x2cos        -0.072481              NAN              NAN             NAN
# L16.x2sin        -0.057630              NAN              NAN             NAN
# L16.x3cos        -0.200436         0.000001      -259561.339           0.000
# L16.x3sin         0.219708              NAN              NAN             NAN
# L16.x4cos         0.741998              NAN              NAN             NAN
# L16.x4sin        -1.401970              NAN              NAN             NAN
# L17.x0sin        -5.467533         0.000000    -19294193.110           0.000
# L17.x1cos        -0.091145              NAN              NAN             NAN
# L17.x1sin         0.329817         0.000001       649451.717           0.000
# L17.x2cos        -0.820757         0.000001     -1125613.530           0.000
# L17.x2sin        -0.218148         0.000003       -76681.850           0.000
# L17.x3cos        -0.062184              NAN              NAN             NAN
# L17.x3sin        -0.010724              NAN              NAN             NAN
# L17.x4cos        -2.295976              NAN              NAN             NAN
# L17.x4sin         2.523013         0.000001      4884045.858           0.000
# L18.x0sin        -9.720205         0.000001    -13945557.153           0.000
# L18.x1cos        -0.631802         0.000000     -1279281.081           0.000
# L18.x1sin         0.627117              NAN              NAN             NAN
# L18.x2cos        -0.292720              NAN              NAN             NAN
# L18.x2sin         0.022810              NAN              NAN             NAN
# L18.x3cos        -0.812022              NAN              NAN             NAN
# L18.x3sin        -0.128507              NAN              NAN             NAN
# L18.x4cos         2.768709              NAN              NAN             NAN
# L18.x4sin        -1.725088              NAN              NAN             NAN
# L19.x0sin         9.942647         0.000001     11862095.243           0.000
# L19.x1cos         0.349527              NAN              NAN             NAN
# L19.x1sin        -0.669990         0.000001      -710628.355           0.000
# L19.x2cos         0.246699              NAN              NAN             NAN
# L19.x2sin        -0.449248              NAN              NAN             NAN
# L19.x3cos         0.622289              NAN              NAN             NAN
# L19.x3sin        -0.133212         0.000001      -101494.283           0.000
# L19.x4cos        -0.237097              NAN              NAN             NAN
# L19.x4sin         1.164310         0.000001      1397852.967           0.000
# L20.x0sin         6.994011              NAN              NAN             NAN
# L20.x1cos        -0.270223              NAN              NAN             NAN
# L20.x1sin         0.109884              NAN              NAN             NAN
# L20.x2cos        -0.355811         0.000001      -263026.950           0.000
# L20.x2sin        -0.532115              NAN              NAN             NAN
# L20.x3cos        -0.404059         0.000001      -276598.530           0.000
# L20.x3sin        -0.287999         0.000001      -545562.188           0.000
# L20.x4cos        -1.649919         0.000001     -2119907.633           0.000
# L20.x4sin        -1.054876              NAN              NAN             NAN
# L21.x0sin       -10.089836              NAN              NAN             NAN
# L21.x1cos        -0.344232              NAN              NAN             NAN
# L21.x1sin        -0.098477         0.000001      -118848.888           0.000
# L21.x2cos        -0.050216         0.000004       -13134.429           0.000
# L21.x2sin        -0.025126         0.000003        -9874.184           0.000
# L21.x3cos         0.091209         0.000001       146414.335           0.000
# L21.x3sin        -0.156697         0.000001      -265895.627           0.000
# L21.x4cos         0.633981              NAN              NAN             NAN
# L21.x4sin        -0.676043         0.000001     -1035977.381           0.000
# L22.x0sin       -10.179556              NAN              NAN             NAN
# L22.x1cos         0.607886              NAN              NAN             NAN
# L22.x1sin        -0.198123              NAN              NAN             NAN
# L22.x2cos         0.574649         0.000003       207689.616           0.000
# L22.x2sin        -0.224284         0.000002      -142157.519           0.000
# L22.x3cos         0.316034         0.000001       446903.131           0.000
# L22.x3sin         0.231517              NAN              NAN             NAN
# L22.x4cos        -0.721775              NAN              NAN             NAN
# L22.x4sin         2.495565              NAN              NAN             NAN
# L23.x0sin        23.253171         0.000001     27717478.357           0.000
# L23.x1cos         0.135165         0.000001        95175.716           0.000
# L23.x1sin        -0.179028              NAN              NAN             NAN
# L23.x2cos        -0.070381              NAN              NAN             NAN
# L23.x2sin        -0.608736              NAN              NAN             NAN
# L23.x3cos        -0.138673              NAN              NAN             NAN
# L23.x3sin        -0.467679              NAN              NAN             NAN
# L23.x4cos         1.575702         0.000001      1667758.619           0.000
# L23.x4sin        -1.682765         0.000001     -2941522.095           0.000
# L24.x0sin        -9.007847              NAN              NAN             NAN
# L24.x1cos        -0.232319              NAN              NAN             NAN
# L24.x1sin         0.601221         0.000001       983563.920           0.000
# L24.x2cos         0.253795              NAN              NAN             NAN
# L24.x2sin         0.249831              NAN              NAN             NAN
# L24.x3cos         0.264898         0.000001       340784.653           0.000
# L24.x3sin         0.235083              NAN              NAN             NAN
# L24.x4cos         0.261216              NAN              NAN             NAN
# L24.x4sin        -0.109127         0.000000      -244810.337           0.000
# L25.x0sin       -10.826862         0.000000    -31274796.876           0.000
# L25.x1cos        -0.066522         0.000000      -202475.708           0.000
# L25.x1sin        -0.123837              NAN              NAN             NAN
# L25.x2cos         0.558386         0.000001       426012.268           0.000
# L25.x2sin         0.104675              NAN              NAN             NAN
# L25.x3cos         0.043389         0.000001        54745.676           0.000
# L25.x3sin         0.143252              NAN              NAN             NAN
# L25.x4cos        -1.970551         0.000000     -9900037.761           0.000
# L25.x4sin         1.421978         0.000000      6391275.615           0.000
# L26.x0sin        11.180229              NAN              NAN             NAN
# L26.x1cos         0.423778         0.000001       451969.143           0.000
# L26.x1sin        -0.148749         0.000000      -440329.312           0.000
# L26.x2cos         0.154677              NAN              NAN             NAN
# L26.x2sin        -0.302694         0.000001      -327784.726           0.000
# L26.x3cos        -0.059346              NAN              NAN             NAN
# L26.x3sin        -0.213071         0.000002      -127691.490           0.000
# L26.x4cos         0.389361              NAN              NAN             NAN
# L26.x4sin        -1.802833         0.000000     -5485133.639           0.000
# L27.x0sin        -0.214238              NAN              NAN             NAN
# L27.x1cos        -0.731280         0.000001     -1296248.860           0.000
# L27.x1sin         0.004567              NAN              NAN             NAN
# L27.x2cos        -0.035025              NAN              NAN             NAN
# L27.x2sin         0.600557              NAN              NAN             NAN
# L27.x3cos         0.307587              NAN              NAN             NAN
# L27.x3sin         0.194850              NAN              NAN             NAN
# L27.x4cos         2.514465         0.000001      3939791.529           0.000
# L27.x4sin         0.157445         0.000000       560480.372           0.000
# L28.x0sin        -2.683775              NAN              NAN             NAN
# L28.x1cos         0.409793         0.000001       298773.533           0.000
# L28.x1sin         0.129203         0.000001       189758.248           0.000
# L28.x2cos         0.521503         0.000003       166315.160           0.000
# L28.x2sin         0.129845         0.000002        79469.821           0.000
# L28.x3cos        -0.130753              NAN              NAN             NAN
# L28.x3sin         0.039550              NAN              NAN             NAN
# L28.x4cos        -3.284211         0.000001     -3167891.224           0.000
# L28.x4sin         0.764649         0.000000      1745310.622           0.000
# L29.x0sin        -1.904682         0.000001     -2139453.840           0.000
# L29.x1cos         0.364116         0.000002       219351.453           0.000
# L29.x1sin        -0.064598         0.000001       -80570.073           0.000
# L29.x2cos        -0.230623         0.000005       -50509.098           0.000
# L29.x2sin         0.268892         0.000002       116068.972           0.000
# L29.x3cos         0.174337              NAN              NAN             NAN
# L29.x3sin         0.460175              NAN              NAN             NAN
# L29.x4cos         0.395239         0.000000      1137665.306           0.000
# L29.x4sin         0.916218         0.000000      3138803.264           0.000
# L30.x0sin         2.630284         0.000001      2681109.236           0.000
# L30.x1cos        -0.718818         0.000002      -301007.274           0.000
# L30.x1sin         0.150557              NAN              NAN             NAN
# L30.x2cos        -0.232242              NAN              NAN             NAN
# L30.x2sin         0.406146         0.000003       151954.243           0.000
# L30.x3cos        -0.397165         0.000000      -855440.126           0.000
# L30.x3sin        -0.181992              NAN              NAN             NAN
# L30.x4cos         2.673615         0.000000      7544869.526           0.000
# L30.x4sin        -1.366932              NAN              NAN             NAN
# L31.x0sin         1.611191         0.000001      1369874.722           0.000
# L31.x1cos         0.099310              NAN              NAN             NAN
# L31.x1sin        -0.243352              NAN              NAN             NAN
# L31.x2cos        -0.292425         0.000003       -90099.446           0.000
# L31.x2sin         0.227424              NAN              NAN             NAN
# L31.x3cos        -0.297306              NAN              NAN             NAN
# L31.x3sin         0.311333              NAN              NAN             NAN
# L31.x4cos        -1.738635              NAN              NAN             NAN
# L31.x4sin         0.234873              NAN              NAN             NAN
# L32.x0sin        -4.253751         0.000001     -7346361.337           0.000
# L32.x1cos         0.331990         0.000001       293320.613           0.000
# L32.x1sin        -0.026841              NAN              NAN             NAN
# L32.x2cos        -0.486894         0.000002      -269764.891           0.000
# L32.x2sin        -0.451405         0.000002      -247059.425           0.000
# L32.x3cos        -0.185610              NAN              NAN             NAN
# L32.x3sin        -0.804002         0.000001      -766968.652           0.000
# L32.x4cos        -0.651194         0.000001     -1300802.095           0.000
# L32.x4sin        -1.268364         0.000001     -1823079.412           0.000
# L33.x0sin         3.189902              NAN              NAN             NAN
# L33.x1cos         0.019021              NAN              NAN             NAN
# L33.x1sin        -0.040535         0.000001       -57094.171           0.000
# L33.x2cos        -0.111476              NAN              NAN             NAN
# L33.x2sin        -0.301381              NAN              NAN             NAN
# L33.x3cos         0.642278         0.000000      2235073.179           0.000
# L33.x3sin        -0.074900              NAN              NAN             NAN
# L33.x4cos         0.596881              NAN              NAN             NAN
# L33.x4sin         3.173890              NAN              NAN             NAN
# L34.x0sin        -1.203223              NAN              NAN             NAN
# L34.x1cos        -0.158857         0.000001      -228718.352           0.000
# L34.x1sin         0.352845         0.000001       615788.360           0.000
# L34.x2cos         0.631355         0.000003       190578.329           0.000
# L34.x2sin        -0.289901         0.000004       -68168.949           0.000
# L34.x3cos        -0.009673         0.000000       -33505.313           0.000
# L34.x3sin         0.484964         0.000001       540986.590           0.000
# L34.x4cos         0.501600              NAN              NAN             NAN
# L34.x4sin        -2.739455         0.000000     -9493192.953           0.000
# L35.x0sin         0.218847         0.000002        97682.849           0.000
# L35.x1cos         0.003300              NAN              NAN             NAN
# L35.x1sin        -0.259984         0.000001      -201211.771           0.000
# L35.x2cos        -0.082421         0.000003       -26412.323           0.000
# L35.x2sin         0.397122              NAN              NAN             NAN
# L35.x3cos        -0.188269         0.000001      -265899.272           0.000
# L35.x3sin        -0.114807         0.000001      -126830.348           0.000
# L35.x4cos        -0.545552         0.000000     -1190542.766           0.000
# L35.x4sin         1.050113         0.000000      2612016.161           0.000
# L36.x0sin        -0.012069         0.000001        -8121.733           0.000
# L36.x1cos         0.022223         0.000001        28859.065           0.000
# L36.x1sin         0.051638              NAN              NAN             NAN
# L36.x2cos        -0.048269         0.000001       -37009.162           0.000
# L36.x2sin        -0.063740         0.000002       -30994.471           0.000
# L36.x3cos         0.037486         0.000001        42780.591           0.000
# L36.x3sin        -0.012413         0.000001       -22524.766           0.000
# L36.x4cos         0.135638         0.000000       652891.486           0.000
# L36.x4sin        -0.152276              NAN              NAN             NAN
# ============================================================================
#
# Results for equation x1cos
# ============================================================================
#                coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------
# L1.x0sin         -0.027750         0.000001       -46209.696           0.000
# L1.x1cos          6.047223              NAN              NAN             NAN
# L1.x1sin         -2.711340         0.000000     -6327738.596           0.000
# L1.x2cos         -0.019915         0.000001       -18238.256           0.000
# L1.x2sin         -0.013424         0.000003        -4926.047           0.000
# L1.x3cos         -0.018668              NAN              NAN             NAN
# L1.x3sin         -0.008723         0.000001       -12862.840           0.000
# L1.x4cos         -0.009439         0.000000       -24829.567           0.000
# L1.x4sin         -0.013020              NAN              NAN             NAN
# L2.x0sin          0.238910              NAN              NAN             NAN
# L2.x1cos        -11.881542              NAN              NAN             NAN
# L2.x1sin         13.317716              NAN              NAN             NAN
# L2.x2cos          0.103916              NAN              NAN             NAN
# L2.x2sin         -0.025047         0.000004        -6576.320           0.000
# L2.x3cos          0.116664         0.000001       129196.925           0.000
# L2.x3sin         -0.039082              NAN              NAN             NAN
# L2.x4cos          0.033661         0.000000      1435768.320           0.000
# L2.x4sin          0.022526              NAN              NAN             NAN
# L3.x0sin         -0.918400         0.000000     -2024255.687           0.000
# L3.x1cos          7.039817              NAN              NAN             NAN
# L3.x1sin        -21.863708              NAN              NAN             NAN
# L3.x2cos         -0.042683              NAN              NAN             NAN
# L3.x2sin          0.109931              NAN              NAN             NAN
# L3.x3cos         -0.137432              NAN              NAN             NAN
# L3.x3sin          0.257017         0.000001       299526.864           0.000
# L3.x4cos         -0.079080         0.000000      -423569.223           0.000
# L3.x4sin          0.259243         0.000000      1541025.225           0.000
# L4.x0sin          1.996152         0.000001      1806215.702           0.000
# L4.x1cos          0.767244              NAN              NAN             NAN
# L4.x1sin          9.888504              NAN              NAN             NAN
# L4.x2cos         -0.003914         0.000000       -11394.836           0.000
# L4.x2sin          0.194313              NAN              NAN             NAN
# L4.x3cos         -0.078591         0.000001      -109256.047           0.000
# L4.x3sin         -0.297084              NAN              NAN             NAN
# L4.x4cos          0.338294         0.000001       415951.748           0.000
# L4.x4sin         -1.300737              NAN              NAN             NAN
# L5.x0sin         -2.447880         0.000001     -2173577.427           0.000
# L5.x1cos          3.849961              NAN              NAN             NAN
# L5.x1sin          5.640423              NAN              NAN             NAN
# L5.x2cos         -0.482550              NAN              NAN             NAN
# L5.x2sin         -0.276570         0.000002      -177209.094           0.000
# L5.x3cos          0.029752              NAN              NAN             NAN
# L5.x3sin          0.033452              NAN              NAN             NAN
# L5.x4cos         -0.974421              NAN              NAN             NAN
# L5.x4sin          2.700727              NAN              NAN             NAN
# L6.x0sin          1.046916         0.000000      2729872.277           0.000
# L6.x1cos         -3.564647         0.000001     -3053432.388           0.000
# L6.x1sin         -2.598281         0.000001     -3627904.852           0.000
# L6.x2cos          0.356961              NAN              NAN             NAN
# L6.x2sin         -0.312308              NAN              NAN             NAN
# L6.x3cos          0.217283              NAN              NAN             NAN
# L6.x3sin         -0.083973         0.000000      -182341.541           0.000
# L6.x4cos          1.182190         0.000000      2529742.328           0.000
# L6.x4sin         -3.011987              NAN              NAN             NAN
# L7.x0sin          1.516491         0.000001      1742795.553           0.000
# L7.x1cos         -5.455344         0.000000    -11861927.790           0.000
# L7.x1sin         -0.618426         0.000000     -1501372.556           0.000
# L7.x2cos          0.269515              NAN              NAN             NAN
# L7.x2sin          0.268659         0.000001       468407.045           0.000
# L7.x3cos         -0.136643         0.000000      -362394.732           0.000
# L7.x3sin          0.229922              NAN              NAN             NAN
# L7.x4cos          0.183379              NAN              NAN             NAN
# L7.x4sin          1.741388              NAN              NAN             NAN
# L8.x0sin         -2.290856              NAN              NAN             NAN
# L8.x1cos          1.003782         0.000001       777918.321           0.000
# L8.x1sin         -0.200705         0.000001      -247053.581           0.000
# L8.x2cos         -0.333007              NAN              NAN             NAN
# L8.x2sin         -0.243320         0.000002      -104017.857           0.000
# L8.x3cos          0.114996         0.000000       491428.881           0.000
# L8.x3sin         -0.192711              NAN              NAN             NAN
# L8.x4cos         -2.227867              NAN              NAN             NAN
# L8.x4sin          0.124985         0.000000       411197.152           0.000
# L9.x0sin         -0.675777              NAN              NAN             NAN
# L9.x1cos          4.070339              NAN              NAN             NAN
# L9.x1sin         -3.437590         0.000000     -7928554.662           0.000
# L9.x2cos          0.588226              NAN              NAN             NAN
# L9.x2sin          0.357880              NAN              NAN             NAN
# L9.x3cos         -0.233588              NAN              NAN             NAN
# L9.x3sin          0.261009              NAN              NAN             NAN
# L9.x4cos          2.647181         0.000000     18491806.261           0.000
# L9.x4sin         -1.841307         0.000001     -3264324.151           0.000
# L10.x0sin         5.454937              NAN              NAN             NAN
# L10.x1cos        -0.239712              NAN              NAN             NAN
# L10.x1sin        -0.206831         0.000001      -251197.238           0.000
# L10.x2cos        -0.575417         0.000002      -377821.390           0.000
# L10.x2sin        -0.111685              NAN              NAN             NAN
# L10.x3cos         0.247349              NAN              NAN             NAN
# L10.x3sin        -0.360377              NAN              NAN             NAN
# L10.x4cos        -0.811396         0.000001     -1445365.549           0.000
# L10.x4sin         2.439147         0.000000      5102879.527           0.000
# L11.x0sin        -8.155857         0.000001    -12694585.221           0.000
# L11.x1cos         0.003221              NAN              NAN             NAN
# L11.x1sin         2.469441              NAN              NAN             NAN
# L11.x2cos         0.521315         0.000002       218404.492           0.000
# L11.x2sin        -0.089875         0.000001      -139366.776           0.000
# L11.x3cos        -0.010284              NAN              NAN             NAN
# L11.x3sin         0.268310              NAN              NAN             NAN
# L11.x4cos        -1.954733         0.000001     -2836156.696           0.000
# L11.x4sin        -0.610008         0.000000     -2169607.932           0.000
# L12.x0sin         6.920545              NAN              NAN             NAN
# L12.x1cos         1.322558              NAN              NAN             NAN
# L12.x1sin         1.592979              NAN              NAN             NAN
# L12.x2cos        -0.295500         0.000000      -599827.874           0.000
# L12.x2sin         0.513458         0.000002       334799.009           0.000
# L12.x3cos        -0.138051         0.000001      -142679.380           0.000
# L12.x3sin         0.173350              NAN              NAN             NAN
# L12.x4cos         3.337976         0.000000      8683331.407           0.000
# L12.x4sin        -2.239358              NAN              NAN             NAN
# L13.x0sin        -2.685592              NAN              NAN             NAN
# L13.x1cos        -0.714790              NAN              NAN             NAN
# L13.x1sin         0.184984              NAN              NAN             NAN
# L13.x2cos         0.000082              NAN              NAN             NAN
# L13.x2sin        -0.410119              NAN              NAN             NAN
# L13.x3cos        -0.119444              NAN              NAN             NAN
# L13.x3sin        -0.286581              NAN              NAN             NAN
# L13.x4cos        -1.306026              NAN              NAN             NAN
# L13.x4sin         2.899053         0.000001      3548238.030           0.000
# L14.x0sin        -2.455299              NAN              NAN             NAN
# L14.x1cos        -2.254286         0.000001     -4001307.071           0.000
# L14.x1sin        -0.880932              NAN              NAN             NAN
# L14.x2cos        -0.090521              NAN              NAN             NAN
# L14.x2sin         0.459855              NAN              NAN             NAN
# L14.x3cos         0.173070         0.000001       218319.075           0.000
# L14.x3sin        -0.084039         0.000000      -215807.262           0.000
# L14.x4cos        -2.450218              NAN              NAN             NAN
# L14.x4sin        -0.962624              NAN              NAN             NAN
# L15.x0sin         5.808258         0.000001      6833758.737           0.000
# L15.x1cos        -0.650442         0.000001      -596696.604           0.000
# L15.x1sin        -0.180267         0.000000      -655839.696           0.000
# L15.x2cos        -0.282071              NAN              NAN             NAN
# L15.x2sin        -0.475112              NAN              NAN             NAN
# L15.x3cos        -0.096076              NAN              NAN             NAN
# L15.x3sin         0.261864              NAN              NAN             NAN
# L15.x4cos         3.581417              NAN              NAN             NAN
# L15.x4sin        -1.281207              NAN              NAN             NAN
# L16.x0sin        -4.927688              NAN              NAN             NAN
# L16.x1cos         1.455149         0.000000      3395599.262           0.000
# L16.x1sin        -0.012471         0.000001       -19307.111           0.000
# L16.x2cos         0.164921              NAN              NAN             NAN
# L16.x2sin         0.017299              NAN              NAN             NAN
# L16.x3cos         0.105454         0.000001       166930.306           0.000
# L16.x3sin        -0.403017              NAN              NAN             NAN
# L16.x4cos        -1.545606              NAN              NAN             NAN
# L16.x4sin         1.415874              NAN              NAN             NAN
# L17.x0sin         0.488658         0.000000      2107898.070           0.000
# L17.x1cos        -0.332933              NAN              NAN             NAN
# L17.x1sin        -1.333997         0.000000     -3210985.075           0.000
# L17.x2cos         0.339933         0.000001       569873.052           0.000
# L17.x2sin        -0.248970         0.000002      -106978.457           0.000
# L17.x3cos         0.230350              NAN              NAN             NAN
# L17.x3sin         0.351106              NAN              NAN             NAN
# L17.x4cos        -0.454916              NAN              NAN             NAN
# L17.x4sin         1.550447         0.000000      3668825.011           0.000
# L18.x0sin         3.154748         0.000001      5532671.090           0.000
# L18.x1cos         0.605788         0.000000      1499394.460           0.000
# L18.x1sin        -0.087866              NAN              NAN             NAN
# L18.x2cos         0.003500              NAN              NAN             NAN
# L18.x2sin         0.537921              NAN              NAN             NAN
# L18.x3cos        -0.243064              NAN              NAN             NAN
# L18.x3sin         0.179678              NAN              NAN             NAN
# L18.x4cos         1.221995              NAN              NAN             NAN
# L18.x4sin        -4.791240              NAN              NAN             NAN
# L19.x0sin        -2.861170         0.000001     -4172658.024           0.000
# L19.x1cos         0.092331              NAN              NAN             NAN
# L19.x1sin         0.750858         0.000001       973512.401           0.000
# L19.x2cos        -0.291463              NAN              NAN             NAN
# L19.x2sin         0.075599              NAN              NAN             NAN
# L19.x3cos        -0.241518              NAN              NAN             NAN
# L19.x3sin        -0.097090         0.000001       -90424.309           0.000
# L19.x4cos        -1.610190              NAN              NAN             NAN
# L19.x4sin         3.610075         0.000001      5298083.880           0.000
# L20.x0sin         0.803549              NAN              NAN             NAN
# L20.x1cos         0.625270              NAN              NAN             NAN
# L20.x1sin         0.476856              NAN              NAN             NAN
# L20.x2cos        -0.019759         0.000001       -17855.046           0.000
# L20.x2sin        -0.166037              NAN              NAN             NAN
# L20.x3cos         0.013471         0.000001        11272.771           0.000
# L20.x3sin        -0.256663         0.000000      -594330.068           0.000
# L20.x4cos         1.393289         0.000001      2188291.880           0.000
# L20.x4sin         1.222774              NAN              NAN             NAN
# L21.x0sin        -1.055117              NAN              NAN             NAN
# L21.x1cos        -0.677110              NAN              NAN             NAN
# L21.x1sin        -0.091069         0.000001      -134350.608           0.000
# L21.x2cos        -0.298893         0.000003       -95563.582           0.000
# L21.x2sin        -0.106006         0.000002       -50923.418           0.000
# L21.x3cos         0.293507         0.000001       575932.825           0.000
# L21.x3sin        -0.168358         0.000000      -349214.448           0.000
# L21.x4cos        -0.506448              NAN              NAN             NAN
# L21.x4sin        -3.653682         0.000001     -6844099.195           0.000
# L22.x0sin         3.582577              NAN              NAN             NAN
# L22.x1cos         0.376209              NAN              NAN             NAN
# L22.x1sin        -0.046411              NAN              NAN             NAN
# L22.x2cos         0.187880         0.000002        83004.672           0.000
# L22.x2sin         0.027814         0.000001        21549.631           0.000
# L22.x3cos        -0.041228         0.000001       -71265.182           0.000
# L22.x3sin         0.518946              NAN              NAN             NAN
# L22.x4cos         0.215002              NAN              NAN             NAN
# L22.x4sin         2.043596              NAN              NAN             NAN
# L23.x0sin        -4.935541         0.000001     -7191442.798           0.000
# L23.x1cos        -0.526527         0.000001      -453202.297           0.000
# L23.x1sin         0.255194              NAN              NAN             NAN
# L23.x2cos        -0.088422              NAN              NAN             NAN
# L23.x2sin        -0.478464              NAN              NAN             NAN
# L23.x3cos        -0.253121              NAN              NAN             NAN
# L23.x3sin        -0.230367              NAN              NAN             NAN
# L23.x4cos        -0.321103         0.000001      -415444.880           0.000
# L23.x4sin        -0.748435         0.000000     -1599236.527           0.000
# L24.x0sin         3.829531              NAN              NAN             NAN
# L24.x1cos        -0.039152              NAN              NAN             NAN
# L24.x1sin         0.484086         0.000001       968055.890           0.000
# L24.x2cos         0.288025              NAN              NAN             NAN
# L24.x2sin         0.117331              NAN              NAN             NAN
# L24.x3cos         0.069825         0.000001       109804.948           0.000
# L24.x3sin        -0.399460              NAN              NAN             NAN
# L24.x4cos        -0.194427              NAN              NAN             NAN
# L24.x4sin         0.983655         0.000000      2697440.674           0.000
# L25.x0sin        -2.203595         0.000000     -7780964.647           0.000
# L25.x1cos        -0.661990         0.000000     -2463005.688           0.000
# L25.x1sin        -0.613938              NAN              NAN             NAN
# L25.x2cos         0.278073         0.000001       259332.135           0.000
# L25.x2sin         0.137045              NAN              NAN             NAN
# L25.x3cos         0.293966         0.000001       453394.965           0.000
# L25.x3sin         0.436417              NAN              NAN             NAN
# L25.x4cos        -0.359525         0.000000     -2207943.071           0.000
# L25.x4sin        -0.478420         0.000000     -2628535.298           0.000
# L26.x0sin         1.052734              NAN              NAN             NAN
# L26.x1cos         0.494254         0.000001       644362.770           0.000
# L26.x1sin        -0.686525         0.000000     -2484215.622           0.000
# L26.x2cos        -0.186375              NAN              NAN             NAN
# L26.x2sin         0.173448         0.000001       229595.298           0.000
# L26.x3cos        -0.172960              NAN              NAN             NAN
# L26.x3sin        -0.314680         0.000001      -230524.190           0.000
# L26.x4cos         2.700715              NAN              NAN             NAN
# L26.x4sin         0.408818         0.000000      1520445.383           0.000
# L27.x0sin         0.844937              NAN              NAN             NAN
# L27.x1cos         0.035841         0.000000        77659.765           0.000
# L27.x1sin        -0.018537              NAN              NAN             NAN
# L27.x2cos        -0.086529              NAN              NAN             NAN
# L27.x2sin        -0.015859              NAN              NAN             NAN
# L27.x3cos         0.350380              NAN              NAN             NAN
# L27.x3sin         0.190778              NAN              NAN             NAN
# L27.x4cos        -3.317145         0.000001     -6353336.464           0.000
# L27.x4sin        -1.855738         0.000000     -8075281.933           0.000
# L28.x0sin        -3.555131              NAN              NAN             NAN
# L28.x1cos         0.391008         0.000001       348476.017           0.000
# L28.x1sin         0.291501         0.000001       523334.512           0.000
# L28.x2cos         0.000438         0.000003          170.798           0.000
# L28.x2sin        -0.022046         0.000001       -16493.608           0.000
# L28.x3cos        -0.192857              NAN              NAN             NAN
# L28.x3sin         0.341414              NAN              NAN             NAN
# L28.x4cos         1.086317         0.000001      1280871.263           0.000
# L28.x4sin         1.755840         0.000000      4898974.812           0.000
# L29.x0sin         4.817624         0.000001      6614896.517           0.000
# L29.x1cos         0.611947         0.000001       450634.551           0.000
# L29.x1sin        -0.009698         0.000001       -14785.867           0.000
# L29.x2cos         0.143679         0.000004        38465.369           0.000
# L29.x2sin        -0.115370         0.000002       -60875.359           0.000
# L29.x3cos        -0.257677              NAN              NAN             NAN
# L29.x3sin        -0.134054              NAN              NAN             NAN
# L29.x4cos         0.649548         0.000000      2285474.163           0.000
# L29.x4sin         0.342383         0.000000      1433795.879           0.000
# L30.x0sin        -3.313007         0.000001     -4128040.627           0.000
# L30.x1cos        -0.538553         0.000002      -275674.089           0.000
# L30.x1sin         1.082923              NAN              NAN             NAN
# L30.x2cos        -0.115217              NAN              NAN             NAN
# L30.x2sin         0.292804         0.000002       133911.476           0.000
# L30.x3cos         0.100721         0.000000       265185.842           0.000
# L30.x3sin        -0.132278              NAN              NAN             NAN
# L30.x4cos        -0.833529         0.000000     -2875300.948           0.000
# L30.x4sin        -1.155992              NAN              NAN             NAN
# L31.x0sin         0.632619         0.000001       657485.340           0.000
# L31.x1cos        -0.672298              NAN              NAN             NAN
# L31.x1sin        -0.781043              NAN              NAN             NAN
# L31.x2cos         0.052570         0.000003        19799.624           0.000
# ...
# L15.x3cos        -0.005289              NAN              NAN             NAN
# L15.x3sin         0.056535              NAN              NAN             NAN
# L15.x4cos        -1.256199              NAN              NAN             NAN
# L15.x4sin        -2.394586              NAN              NAN             NAN
# L16.x0sin         0.084471              NAN              NAN             NAN
# L16.x1cos         0.153981         0.000000       820957.421           0.000
# L16.x1sin        -0.136533         0.000000      -482962.849           0.000
# L16.x2cos        -0.042188              NAN              NAN             NAN
# L16.x2sin        -0.069801              NAN              NAN             NAN
# L16.x3cos        -0.017463         0.000000       -63157.708           0.000
# L16.x3sin        -0.167241              NAN              NAN             NAN
# L16.x4cos        -0.144654              NAN              NAN             NAN
# L16.x4sin         0.301866              NAN              NAN             NAN
# L17.x0sin         1.078401         0.000000     10628426.130           0.000
# L17.x1cos         0.024886              NAN              NAN             NAN
# L17.x1sin         0.194798         0.000000      1071300.982           0.000
# L17.x2cos        -0.007623         0.000000       -29198.339           0.000
# L17.x2sin         0.035146         0.000001        34503.613           0.000
# L17.x3cos        -0.078918              NAN              NAN             NAN
# L17.x3sin        -0.002459              NAN              NAN             NAN
# L17.x4cos         1.195773              NAN              NAN             NAN
# L17.x4sin         3.124997         0.000000     16895199.292           0.000
# L18.x0sin        -1.960995         0.000000     -7857607.262           0.000
# L18.x1cos        -0.103242         0.000000      -583843.551           0.000
# L18.x1sin        -0.248935              NAN              NAN             NAN
# L18.x2cos        -0.037676              NAN              NAN             NAN
# L18.x2sin        -0.035047              NAN              NAN             NAN
# L18.x3cos         0.043650              NAN              NAN             NAN
# L18.x3sin        -0.013046              NAN              NAN             NAN
# L18.x4cos        -0.459069              NAN              NAN             NAN
# L18.x4sin         0.151208              NAN              NAN             NAN
# L19.x0sin         2.008817         0.000000      6693500.590           0.000
# L19.x1cos         0.080889              NAN              NAN             NAN
# L19.x1sin         0.093405         0.000000       276691.495           0.000
# L19.x2cos        -0.013345              NAN              NAN             NAN
# L19.x2sin         0.113601              NAN              NAN             NAN
# L19.x3cos         0.036869              NAN              NAN             NAN
# L19.x3sin        -0.146901         0.000000      -312591.410           0.000
# L19.x4cos         0.702473              NAN              NAN             NAN
# L19.x4sin        -2.298719         0.000000     -7707831.696           0.000
# L20.x0sin        -1.286982              NAN              NAN             NAN
# L20.x1cos         0.051834              NAN              NAN             NAN
# L20.x1sin         0.088104              NAN              NAN             NAN
# L20.x2cos         0.017630         0.000000        36398.001           0.000
# L20.x2sin        -0.200051              NAN              NAN             NAN
# L20.x3cos         0.111550         0.000001       213269.730           0.000
# L20.x3sin         0.083086         0.000000       439579.875           0.000
# L20.x4cos        -0.033432         0.000000      -119969.242           0.000
# L20.x4sin        -1.376082              NAN              NAN             NAN
# L21.x0sin         0.245566              NAN              NAN             NAN
# L21.x1cos        -0.097613              NAN              NAN             NAN
# L21.x1sin        -0.021890         0.000000       -73783.188           0.000
# L21.x2cos        -0.180684         0.000001      -131989.888           0.000
# L21.x2sin         0.181584         0.000001       199300.123           0.000
# L21.x3cos        -0.013628         0.000000       -61098.263           0.000
# L21.x3sin         0.071305         0.000000       337929.573           0.000
# L21.x4cos        -1.074476              NAN              NAN             NAN
# L21.x4sin         1.379357         0.000000      5903452.526           0.000
# L22.x0sin         0.413605              NAN              NAN             NAN
# L22.x1cos         0.049072              NAN              NAN             NAN
# L22.x1sin        -0.049887              NAN              NAN             NAN
# L22.x2cos         0.137746         0.000001       139040.991           0.000
# L22.x2sin        -0.203595         0.000001      -360406.815           0.000
# L22.x3cos        -0.188506         0.000000      -744490.245           0.000
# L22.x3sin        -0.003950              NAN              NAN             NAN
# L22.x4cos        -1.047036              NAN              NAN             NAN
# L22.x4sin         2.239395              NAN              NAN             NAN
# L23.x0sin        -0.467765         0.000000     -1557230.561           0.000
# L23.x1cos         0.044009         0.000001        86547.306           0.000
# L23.x1sin         0.017608              NAN              NAN             NAN
# L23.x2cos        -0.059654              NAN              NAN             NAN
# L23.x2sin         0.018859              NAN              NAN             NAN
# L23.x3cos         0.258442              NAN              NAN             NAN
# L23.x3sin        -0.167923              NAN              NAN             NAN
# L23.x4cos         1.894625         0.000000      5600617.443           0.000
# L23.x4sin        -0.016560         0.000000       -80844.423           0.000
# L24.x0sin         0.387899              NAN              NAN             NAN
# L24.x1cos        -0.257632              NAN              NAN             NAN
# L24.x1sin         0.083436         0.000000       381221.475           0.000
# L24.x2cos        -0.034331              NAN              NAN             NAN
# L24.x2sin        -0.091011              NAN              NAN             NAN
# L24.x3cos        -0.160274         0.000000      -575861.881           0.000
# L24.x3sin         0.067042              NAN              NAN             NAN
# L24.x4cos         0.870241              NAN              NAN             NAN
# L24.x4sin        -3.086105         0.000000    -19335869.676           0.000
# L25.x0sin        -0.253455         0.000000     -2044777.750           0.000
# L25.x1cos         0.178167         0.000000      1514558.928           0.000
# L25.x1sin        -0.087341              NAN              NAN             NAN
# L25.x2cos         0.197608         0.000000       421060.845           0.000
# L25.x2sin         0.046526              NAN              NAN             NAN
# L25.x3cos         0.277394         0.000000       977508.378           0.000
# L25.x3sin         0.113721              NAN              NAN             NAN
# L25.x4cos         0.203679         0.000000      2857913.449           0.000
# L25.x4sin         0.667755         0.000000      8382337.232           0.000
# L26.x0sin        -0.561454              NAN              NAN             NAN
# L26.x1cos         0.176758         0.000000       526505.919           0.000
# L26.x1sin        -0.211330         0.000000     -1747183.274           0.000
# L26.x2cos        -0.091133              NAN              NAN             NAN
# L26.x2sin        -0.114709         0.000000      -346925.782           0.000
# L26.x3cos        -0.229815              NAN              NAN             NAN
# L26.x3sin        -0.007446         0.000001       -12462.400           0.000
# L26.x4cos        -2.944641              NAN              NAN             NAN
# L26.x4sin         0.418785         0.000000      3558572.052           0.000
# L27.x0sin         1.942327              NAN              NAN             NAN
# L27.x1cos        -0.280765         0.000000     -1389954.262           0.000
# L27.x1sin         0.237770              NAN              NAN             NAN
# L27.x2cos         0.140284              NAN              NAN             NAN
# L27.x2sin         0.183394              NAN              NAN             NAN
# L27.x3cos         0.000718              NAN              NAN             NAN
# L27.x3sin        -0.024046              NAN              NAN             NAN
# L27.x4cos         0.276814         0.000000      1211347.063           0.000
# L27.x4sin         0.672222         0.000000      6683403.771           0.000
# L28.x0sin        -2.545332              NAN              NAN             NAN
# L28.x1cos         0.252361         0.000000       513869.298           0.000
# L28.x1sin         0.122800         0.000000       503711.804           0.000
# L28.x2cos        -0.097958         0.000001       -87250.988           0.000
# L28.x2sin        -0.157051         0.000001      -268454.578           0.000
# L28.x3cos         0.204609              NAN              NAN             NAN
# L28.x3sin         0.020784              NAN              NAN             NAN
# L28.x4cos         1.093355         0.000000      2945464.080           0.000
# L28.x4sin         0.549457         0.000000      3502656.066           0.000
# L29.x0sin         1.604355         0.000000      5033086.042           0.000
# L29.x1cos        -0.127914         0.000001      -215214.467           0.000
# L29.x1sin        -0.148307         0.000000      -516622.779           0.000
# L29.x2cos         0.191855         0.000002       117352.696           0.000
# L29.x2sin         0.173220         0.000001       208828.215           0.000
# L29.x3cos        -0.243917              NAN              NAN             NAN
# L29.x3sin         0.143264              NAN              NAN             NAN
# L29.x4cos         2.022564         0.000000     16259641.211           0.000
# L29.x4sin        -0.004819         0.000000       -46107.232           0.000
# L30.x0sin        -0.096938         0.000000      -275968.109           0.000
# L30.x1cos        -0.064433         0.000001       -75356.403           0.000
# L30.x1sin        -0.063475              NAN              NAN             NAN
# L30.x2cos        -0.151039              NAN              NAN             NAN
# L30.x2sin        -0.032153         0.000001       -33597.776           0.000
# L30.x3cos         0.000286         0.000000         1720.275           0.000
# L30.x3sin        -0.060731              NAN              NAN             NAN
# L30.x4cos        -1.370265         0.000000    -10799686.538           0.000
# L30.x4sin        -2.500682              NAN              NAN             NAN
# L31.x0sin        -0.633321         0.000000     -1503872.998           0.000
# L31.x1cos        -0.062317              NAN              NAN             NAN
# L31.x1sin         0.138699              NAN              NAN             NAN
# L31.x2cos         0.045048         0.000001        38764.792           0.000
# L31.x2sin         0.091986              NAN              NAN             NAN
# L31.x3cos        -0.091087              NAN              NAN             NAN
# L31.x3sin        -0.143195              NAN              NAN             NAN
# L31.x4cos        -1.440270              NAN              NAN             NAN
# L31.x4sin         1.023675              NAN              NAN             NAN
# L32.x0sin         0.455365         0.000000      2196408.514           0.000
# L32.x1cos         0.317475         0.000000       783393.838           0.000
# L32.x1sin        -0.131304              NAN              NAN             NAN
# L32.x2cos        -0.028756         0.000001       -44496.720           0.000
# L32.x2sin        -0.001116         0.000001        -1706.501           0.000
# L32.x3cos         0.127792              NAN              NAN             NAN
# L32.x3sin        -0.032300         0.000000       -86056.184           0.000
# L32.x4cos        -0.847950         0.000000     -4730690.948           0.000
# L32.x4sin         1.929766         0.000000      7746754.341           0.000
# L33.x0sin        -0.082318              NAN              NAN             NAN
# L33.x1cos        -0.340656              NAN              NAN             NAN
# L33.x1sin         0.049221         0.000000       193627.976           0.000
# L33.x2cos        -0.187171              NAN              NAN             NAN
# L33.x2sin        -0.017697              NAN              NAN             NAN
# L33.x3cos         0.088173         0.000000       856956.174           0.000
# L33.x3sin         0.037463              NAN              NAN             NAN
# L33.x4cos         4.445698              NAN              NAN             NAN
# L33.x4sin        -1.364830              NAN              NAN             NAN
# L34.x0sin        -0.057257              NAN              NAN             NAN
# L34.x1cos         0.220882         0.000000       888193.713           0.000
# L34.x1sin         0.026503         0.000000       129178.825           0.000
# L34.x2cos         0.158332         0.000001       133481.534           0.000
# L34.x2sin        -0.145854         0.000002       -95787.586           0.000
# L34.x3cos        -0.070069         0.000000      -677843.069           0.000
# L34.x3sin         0.087900         0.000000       273854.368           0.000
# L34.x4cos        -3.856781              NAN              NAN             NAN
# L34.x4sin        -0.407567         0.000000     -3944579.615           0.000
# L35.x0sin         0.036174         0.000001        45095.300           0.000
# L35.x1cos        -0.094569              NAN              NAN             NAN
# L35.x1sin        -0.019356         0.000000       -41838.153           0.000
# L35.x2cos        -0.001683         0.000001        -1505.888           0.000
# L35.x2sin         0.096992              NAN              NAN             NAN
# L35.x3cos        -0.011467         0.000000       -45232.586           0.000
# L35.x3sin        -0.048951         0.000000      -151031.557           0.000
# L35.x4cos         1.400216         0.000000      8534095.085           0.000
# L35.x4sin         0.595840         0.000000      4139262.655           0.000
# L36.x0sin        -0.006533         0.000001       -12277.727           0.000
# L36.x1cos         0.018329         0.000000        66480.095           0.000
# L36.x1sin         0.001384              NAN              NAN             NAN
# L36.x2cos        -0.011663         0.000000       -24974.752           0.000
# L36.x2sin        -0.011734         0.000001       -15935.912           0.000
# L36.x3cos         0.007185         0.000000        22901.671           0.000
# L36.x3sin         0.004122         0.000000        20891.678           0.000
# L36.x4cos        -0.189324         0.000000     -2545178.684           0.000
# L36.x4sin        -0.145668              NAN              NAN             NAN
# ============================================================================
#
# Correlation matrix of residuals
#             x0sin     x1cos     x1sin     x2cos     x2sin     x3cos     x3sin     x4cos     x4sin
# x0sin    1.000000  0.053997 -0.061375 -0.039071 -0.106223 -0.133876  0.032566  0.273612  0.086613
# x1cos    0.053997  1.000000 -0.006105 -0.026639 -0.023883 -0.004594  0.004074  0.053086  0.040962
# x1sin   -0.061375 -0.006105  1.000000  0.001558 -0.003514  0.034229  0.001250 -0.027190  0.014015
# x2cos   -0.039071 -0.026639  0.001558  1.000000  0.006946  0.029432 -0.015318 -0.050882 -0.000477
# x2sin   -0.106223 -0.023883 -0.003514  0.006946  1.000000  0.015700  0.001152 -0.084505 -0.033366
# x3cos   -0.133876 -0.004594  0.034229  0.029432  0.015700  1.000000 -0.041136 -0.078066 -0.055310
# x3sin    0.032566  0.004074  0.001250 -0.015318  0.001152 -0.041136  1.000000  0.079155  0.016900
# x4cos    0.273612  0.053086 -0.027190 -0.050882 -0.084505 -0.078066  0.079155  1.000000  0.130794
# x4sin    0.086613  0.040962  0.014015 -0.000477 -0.033366 -0.055310  0.016900  0.130794  1.000000

# %%
# Wald Test
causal_results = results.test_causality('x0sin', 'x1cos', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0sin', 'x1sin', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0sin', 'x2cos', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0sin', 'x2sin', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0sin', 'x3cos', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0sin', 'x3sin', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0sin', 'x4cos', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0sin', 'x4sin', kind='Wald')
print(causal_results.summary())
# Out:
# Granger causality Wald-test. H_0: x1cos does not Granger-cause x0sin. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   1.904e+13        51.00       0.000  36
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x1sin does not Granger-cause x0sin. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   3.414e+12        51.00       0.000  36
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x2cos does not Granger-cause x0sin. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   -1.892e+14       51.00       1.000  36
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x2sin does not Granger-cause x0sin. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   5.521e+10        51.00       0.000  36
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x3cos does not Granger-cause x0sin. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   2.672e+12        51.00       0.000  36
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x3sin does not Granger-cause x0sin. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   1.529e+13        51.00       0.000  36
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x4cos does not Granger-cause x0sin. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   -2.555e+14       51.00       1.000  36
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x4sin does not Granger-cause x0sin. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   -3.500e+14       51.00       1.000  36
# ----------------------------------------

# %% [markdown]
# # No Coupling

# %%
# these are our constants
N = 5  # number of variables
K = 0 #coupling
omega =  np.array([ 2.31246433, 35.50794494, 53.41350736, 50.23353682,  5.63392492])  # natural frequency
theta0 = np.array([117.35002435, 261.94283291, 260.06912657, 293.69995793,235.11319532]) # initial state 
tinit = 0.0
tmax = 100.0
dt =  0.01

# %%
kuramoto = Kuramoto(N,K,omega)
sol = kuramoto.integrate(tinit, 20, dt, theta0)
kuramoto.evolution_plot()
kuramoto.trajectory_plot()

# %%
kuramoto = Kuramoto(N,K,omega)
sol = kuramoto.integrate(tinit, tmax, dt, theta0)
kuramoto.evolution_plot()
kuramoto.trajectory_plot()

# %%
kuramoto_df = pd.DataFrame(data= sol[1],    
                columns=['x0','x1','x2','x3','x4'])
kuramoto_df = kuramoto_df.transform([np.cos,np.sin])
kuramoto_df.columns = [''.join(col).strip() for col in kuramoto_df.columns.values]

# %%
kuramoto_df_wo_x0sin=kuramoto_df.drop(columns=['x0cos'])
model = VAR(kuramoto_df_wo_x0sin)
#find optimal lag order by information criteria
lag_orders_data = model.select_order(trend='nc')
print(lag_orders_data.selected_orders)
results = model.fit(lag_orders_data.selected_orders['bic'],trend='nc')
# Out:
# {'aic': 7, 'bic': 7, 'hqic': 7, 'fpe': 7}

# %%
# Wald Test
causal_results = results.test_causality('x0sin', 'x1cos', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0sin', 'x1sin', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0sin', 'x2cos', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0sin', 'x2sin', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0sin', 'x3cos', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0sin', 'x3sin', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0sin', 'x4cos', kind='Wald')
print(causal_results.summary())

print('\t\t')

causal_results = results.test_causality('x0sin', 'x4sin', kind='Wald')
print(causal_results.summary())
# Out:
# Granger causality Wald-test. H_0: x1cos does not Granger-cause x0sin. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   -1.966e+16       14.07       1.000  7
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x1sin does not Granger-cause x0sin. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   1.653e+17        14.07       0.000  7
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x2cos does not Granger-cause x0sin. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   -5.540e+16       14.07       1.000  7
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x2sin does not Granger-cause x0sin. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   1.381e+16        14.07       0.000  7
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x3cos does not Granger-cause x0sin. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   2.042e+17        14.07       0.000  7
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x3sin does not Granger-cause x0sin. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   -1.170e+16       14.07       1.000  7
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x4cos does not Granger-cause x0sin. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   1.322e+15        14.07       0.000  7
# ----------------------------------------
#
# Granger causality Wald-test. H_0: x4sin does not Granger-cause x0sin. Conclusion: reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#   1.465e+16        14.07       0.000  7
# ----------------------------------------
